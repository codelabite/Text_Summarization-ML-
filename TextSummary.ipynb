# %%
text = """
There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.

An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.

Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.

At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. This is also called the core-set. These algorithms model notions like diversity, coverage, information and representativeness of the summary. Query based summarization techniques, additionally model for relevance of the summary with the query. Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.

Keyphrase extraction
The task is the following. You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. Consider the example text from a news article:

"The Army Corps of Engineers, rushing to meet President Bush's promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".
A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases. These are pulled directly from the text. In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". Abstraction requires a deep understanding of the text, which makes it difficult for a computer system. Keyphrases have many applications. They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.

Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.

Supervised learning approaches
Beginning with the work of Turney,[6] many researchers have approached keyphrase extraction as a supervised machine learning problem. Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?). We assume there are known keyphrases available for a set of training documents. Using the known keyphrases, we can assign positive or negative labels to the examples. Then we learn a classifier that can discriminate between positive and negative examples as a function of the features. Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase. For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases. After training a learner, we can select keyphrases for test documents in the following manner. We apply the same example-generation strategy to the test documents, then run each example through the learner. We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model. If probabilities are given, a threshold is used to select the keyphrases. Keyphrase extractors are generally evaluated using precision and recall. Precision measures how many of the proposed keyphrases are actually correct. Recall measures how many of the true keyphrases your system proposed. The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) ). Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.

Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too). The first choice is exactly how to generate examples. Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords. Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags. Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case. For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words. Thus, recall may suffer. However, generating too many examples can also lead to low precision.

We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases. Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc. The Turney paper used about 12 such features. Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney’s seminal paper.

In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number. Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases. This is the technique used by Turney with C4.5 decision trees. Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.

Once examples and features are created, we need a way to learn to predict keyphrases. Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction. In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm. The extractor follows a series of heuristics to identify keyphrases. The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.

Unsupervised approach: TextRank
Another keyphrase extraction algorithm is TextRank. While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data. Many documents with known keyphrases are needed. Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate. Unsupervised keyphrase extraction removes the need for training data. It approaches the problem from a different angle. Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages. Recall this is based on the notion of "prestige" or "recommendation" from social networks. In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. Thus the algorithm is easily portable to new domains and languages.

TextRank is a general purpose graph-based ranking algorithm for NLP. Essentially, it runs PageRank on a graph specially designed for a particular NLP task. For keyphrase extraction, it builds a graph using some set of text units as vertices. Edges are based on some measure of semantic or lexical similarity between the text unit vertices. Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity. Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).

The vertices should correspond to what we want to rank. Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc. However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases. This has a nice side effect of allowing us to produce keyphrases of arbitrary length. For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. Note that the unigrams placed in the graph can be filtered by part of speech. The authors found that adjectives and nouns were the best to include. Thus, some linguistic knowledge comes into play in this step.

Edges are created based on word co-occurrence in this application of TextRank. Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text. N is typically around 2–10. Thus, "natural" and "language" might be linked in a text about NLP. "Natural" and "processing" would also be linked because they would both appear in the same string of N words. These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.

Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases. The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph. Then the top T vertices/unigrams are selected based on their stationary probabilities. A post- processing step is then applied to merge adjacent instances of these T unigrams. As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.

It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases. One way to think about it is the following. A word that appears multiple times throughout a text may have many different co-occurring neighbors. For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words. Running PageRank/TextRank on the graph is likely to rank "learning" highly. Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification". If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised". If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification". In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".

In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts. A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters. This is similar to densely connected Web pages getting ranked highly by PageRank. This approach has also been used in document summarization, considered below.

Document summarization
Like keyphrase extraction, document summarization aims to identify the essence of a text. The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.

Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. The most common way is using the so-called ROUGE (Recall-Oriented Understudy for Gisting Evaluation) measure. This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. It is recall-based to encourage systems to include all the important topics in the text. Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching. For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.

If there are multiple references, the ROUGE-1 scores are averaged. Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. High-order n-gram ROUGE measures try to judge fluency to some degree. Note that ROUGE is similar to the BLEU measure for machine translation, but BLEU is precision- based, because translation systems favor accuracy.

A promising line in document summarization is adaptive document/text summarization.[8] The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. First summarizes that perform adaptive summarization have been created.[9]

Supervised learning approaches
Supervised text summarization is very much like supervised keyphrase extraction. Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc. The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient. The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 only cares about unigrams.

Maximum entropy-based summarization
During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain. The system was based on a hybrid system using a naive Bayes classifier and statistical language models for modeling salience. Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies. Maximum entropy has also been applied successfully for summarization in the broadcast news domain.

TextRank and LexRank
The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. Then the sentences can be ranked with regard to their similarity to this centroid sentence.

A more principled way to estimate sentence importance is using random walks and eigenvector centrality. LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization. The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.

In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.

The edges between sentences are based on some form of semantic similarity or content overlap. While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score. TextRank uses continuous similarity scores as weights.

In both algorithms, the sentences are ranked by applying PageRank to the resulting graph. A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.

It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.

Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization. The task remains the same in both cases—only the number of sentences to choose from has grown. However, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary. Imagine you have a cluster of news articles on a particular event, and you want to produce one summary. Each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary. To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. The method used is called Cross-Sentence Information Subsumption (CSIS).

These methods work based on the idea that sentences "recommend" other similar sentences to the reader. Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance. The importance of this sentence also stems from the importance of the sentences "recommending" it. Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences. This makes intuitive sense and allows the algorithms to be applied to any arbitrary new text. The methods are domain-independent and easily portable. One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain. However, the unsupervised "recommendation"-based approach applies to any domain.

Multi-document summarization
Main article: Multi-document summarization
Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents. In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. Multi-document summarization may also be done in response to a question.[11]

Multi-document summarization creates information reports that are both concise and comprehensive. With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document. While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]

Incorporating diversity
Multi-document extractive summarization faces a problem of potential redundancy. Ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another). LexRank deals with diversity as a heuristic final stage using CSIS, and other systems have used similar methods, such as Maximal Marginal Relevance (MMR),[12] in trying to eliminate redundancy in information retrieval results. There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks. (An absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.) The algorithm is called GRASSHOPPER.[13] In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).

The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.[14] Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]

A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).

Submodular functions as generic tools for summarization
The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. Submodular functions naturally model notions of coverage, information, representation and diversity. Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization. For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. The set cover function attempts to find a subset of objects which cover a given set of concepts. For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. This is an instance of set cover. Similarly, the facility location problem is a special case of submodular functions. The Facility Location function also naturally models coverage and diversity. Another example of a submodular optimization problem is using a determinantal point process to model diversity. Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization. All these important models encouraging coverage, diversity and information are all submodular. Moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular. Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.

While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization. For example, a simple greedy algorithm admits a constant factor guarantee.[16] Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.

Submodular functions have achieved state-of-the-art for almost all summarization problems. For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization. Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]

Submodular Functions have also been used for other summarization tasks. Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. Similarly, Bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies. Submodular Functions have also successfully been used for summarizing machine learning datasets
"""

# %%
text
# Out:
# '\nThere are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\n\nAn example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\n\nImage collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.\n\nAt a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. This is also called the core-set. These algorithms model notions like diversity, coverage, information and representativeness of the summary. Query based summarization techniques, additionally model for relevance of the summary with the query. Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.\n\nKeyphrase extraction\nThe task is the following. You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. Consider the example text from a news article:\n\n"The Army Corps of Engineers, rushing to meet President Bush\'s promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".\nA keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases. These are pulled directly from the text. In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". Abstraction requires a deep understanding of the text, which makes it difficult for a computer system. Keyphrases have many applications. They can enable document browsi ...

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import re
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest

# %%
x = "Note"

# %%
x = x.lower()
x
# Out:
# 'note'

# %%
text = text.lower()
text
# Out:
# '\nthere are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\n\nan example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). this problem is called multi-document summarization. a related application is summarizing news articles. imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\n\nimage collection summarization is another application example of automatic summarization. it consists in selecting a representative set of images from a larger set of images.[4] a summary in this context is useful to show the most representative images of results in an image collection exploration system. video summarization is a related domain, where the system automatically creates a trailer of a long video. this also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.\n\nat a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. this is also called the core-set. these algorithms model notions like diversity, coverage, information and representativeness of the summary. query based summarization techniques, additionally model for relevance of the summary with the query. some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.\n\nkeyphrase extraction\nthe task is the following. you are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] in the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. for example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. consider the example text from a news article:\n\n"the army corps of engineers, rushing to meet president bush\'s promise to protect new orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by the associated press".\na keyphrase extractor might select "army corps of engineers", "president bush", "new orleans", and "defective flood-control pumps" as keyphrases. these are pulled directly from the text. in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". abstraction requires a deep understanding of the text, which makes it difficult for a computer system. keyphrases have many applications. they can enable document browsi ...

# %%
stop = STOP_WORDS

# %%
stop
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
stop = list(STOP_WORDS)
stop
# Out:
# ['into',
#  'becoming',
#  'wherever',
#  'could',
#  'toward',
#  'part',
#  'under',
#  'anyhow',
#  'ourselves',
#  'various',
#  'while',
#  'at',
#  'when',
#  'least',
#  'show',
#  'although',
#  'indeed',
#  'fifty',
#  'without',
#  'besides',
#  'empty',
#  'which',
#  '’d',
#  '‘m',
#  'else',
#  'get',
#  'via',
#  'them',
#  'using',
#  'before',
#  'same',
#  '’s',
#  'always',
#  'n‘t',
#  'five',
#  'formerly',
#  're',
#  'seem',
#  'whether',
#  'below',
#  'everywhere',
#  'anywhere',
#  'beside',
#  'meanwhile',
#  'quite',
#  "'ve",
#  'others',
#  'make',
#  'whereafter',
#  'behind',
#  'himself',
#  'wherein',
#  'thereupon',
#  'who',
#  'myself',
#  'thru',
#  'thus',
#  'yet',
#  'during',
#  '’re',
#  'being',
#  'latter',
#  'amount',
#  'its',
#  'seeming',
#  'except',
#  'please',
#  '‘ll',
#  '‘re',
#  'twelve',
#  'fifteen',
#  'yours',
#  'a',
#  '’m',
#  'an',
#  'above',
#  'moreover',
#  'against',
#  'further',
#  'forty',
#  'onto',
#  'used',
#  'again',
#  'noone',
#  'and',
#  'some',
#  'mostly',
#  'almost',
#  'go',
#  'hence',
#  'whatever',
#  'our',
#  'three',
#  'hundred',
#  'then',
#  'whence',
#  'anyway',
#  'towards',
#  'she',
#  'what',
#  'amongst',
#  'alone',
#  'per',
#  'more',
#  'somehow',
#  'say',
#  'rather',
#  'after',
#  'no',
#  'between',
#  'whoever',
#  'front',
#  'yourselves',
#  'other',
#  'that',
#  'the',
#  'in',
#  'sixty',
#  'seemed',
#  'must',
#  'less',
#  'neither',
#  'very',
#  'around',
#  '‘s',
#  'are',
#  'down',
#  'ever',
#  'someone',
#  'may',
#  'nothing',
#  'six',
#  'or',
#  'move',
#  'over',
#  'sometime',
#  'last',
#  'upon',
#  'us',
#  'is',
#  'such',
#  'either',
#  'here',
#  'this',
#  'well',
#  'much',
#  'bottom',
#  'often',
#  'not',
#  'would',
#  'sometimes',
#  'keep',
#  'nine',
#  'every',
#  'together',
#  'perhaps',
#  'done',
#  'next',
#  'namely',
#  'call',
#  'full',
#  'these',
#  'among',
#  'eleven',
#  'off',
#  'herein',
#  'becomes',
#  'him',
#  'nobody',
#  'nowhere',
#  'whom',
#  'though',
#  'from',
#  'serious',
#  'as',
#  "'re",
#  'how',
#  'back',
#  'see',
#  'became',
#  'become',
#  'on',
#  'hereupon',
#  'due',
#  'latterly',
#  'however',
#  'whereby',
#  'nor',
#  'only',
#  'whole',
#  'your',
#  'has',
#  'third',
#  'but',
#  'across',
#  'i',
#  'throughout',
#  'if',
#  'does',
#  'you',
#  "'d",
#  'eight',
#  'be',
#  'they',
#  'those',
#  'why',
#  'have',
#  'thereby',
#  'former',
#  'ca',
#  'four',
#  'take',
#  'by',
#  'still',
#  'mine',
#  'everyone',
#  'elsewhere',
#  'we',
#  'both',
#  'through',
#  'anyone',
#  'beyond',
#  'since',
#  'whenever',
#  'can',
#  'he',
#  'unless',
#  'cannot',
#  'another',
#  'had',
#  'each',
#  'two',
#  'too',
#  'itself',
#  'anything',
#  'me',
#  'her',
#  'his',
#  'there',
#  'of',
#  'than',
#  'doing',
#  'ten',
#  'themselves',
#  'whither',
#  'none',
#  'been',
#  'put',
#  'for',
#  'whereupon',
#  'ours',
#  'because',
#  'one',
#  "n't",
#  'their',
#  'hereafter',
#  'something',
#  'thereafter',
#  'whose',
#  'several',
#  'therefore',
#  'enough',
#  'once',
#  'never',
#  'somewhere',
#  'were',
#  '‘d',
#  'few',
#  'any',
#  'along',
#  'whereas',
#  'beforehand',
#  'thence',
#  'all',
#  'own',
#  'top',
#  'hereby',
#  'side',
#  'about',
#  'made',
#  'was',
#  'yourself',
#  '‘ve',
#  'do',
#  'out',
#  'to',
#  'did',
#  'where',
#  'am',
#  'first',
#  'until',
#  'now',
#  'also',
#  'therein',
#  'n’t',
#  'up',
#  'already',
#  'within',
#  'most',
#  'with',
#  'hers',
#  'will',
#  'give',
#  'twenty',
#  'many',
#  'herself',
#  'everything',
#  'otherwise',
#  'should',
#  "'s",
#  'it',
#  'regarding',
#  "'ll",
#  'seems',
#  '’ll',
#  'really',
#  "'m",
#  'so',
#  'nevertheless',
#  'afterwards',
#  'my',
#  'name',
#  'might',
#  'just',
#  'even',
#  '’ve']

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punctuation = punctuation + '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
nlp = spacy.load("en_core_web_sm")

# %%
document = nlp(text)

# %%
document
# Out:
# there are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
# an example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). this problem is called multi-document summarization. a related application is summarizing news articles. imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
# image collection summarization is another application example of automatic summarization. it consists in selecting a representative set of images from a larger set of images.[4] a summary in this context is useful to show the most representative images of results in an image collection exploration system. video summarization is a related domain, where the system automatically creates a trailer of a long video. this also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#
# at a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. this is also called the core-set. these algorithms model notions like diversity, coverage, information and representativeness of the summary. query based summarization techniques, additionally model for relevance of the summary with the query. some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.
#
# keyphrase extraction
# the task is the following. you are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] in the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. for example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. consider the example text from a news article:
#
# "the army corps of engineers, rushing to meet president bush's promise to protect new orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by the associated press".
# a keyphrase extractor might select "army corps of engineers", "president bush", "new orleans", and "defective flood-control pumps" as keyphrases. these are pulled directly from the text. in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". abstraction requires a deep understanding of the text, which makes it difficult for a computer system. keyphrases have many applications. they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
# depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#
# supervised learning approaches
# beginning with the work of turney,[6] many researchers have approached keyphrase extraction as a supervised machine learning problem. given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). we then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?). we assume there are known keyphrases available for a set of training documents. using the known keyphrases, we can assign positive or negative labels to the examples. then we learn a classifier that can discriminate between positive and negative examples as a function of the features. some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase. for instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases. after training a learner, we can select keyphrases for test documents in the following manner. we apply the same example-generation strategy to the test documents, then run each example through the learner. we can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model. if probabilities are given, a threshold is used to select the keyphrases. keyphrase extractors are generally evaluated using precision and recall. precision measures how many of the proposed keyphrases are actually correct. recall measures how many of the true keyphrases your system proposed. the two measures can be combined in an f-score, which is the harmonic mean of the two (f = 2pr/(p + r) ). matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
# designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too). the first choice is exactly how to generate examples. turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords. hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags. ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case. for example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words. thus, recall may suffer. however, generating too many examples can also lead to low precision.
#
# we also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases. typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc. the turney paper used about 12 such features. hulth uses a reduced set of features, which were found most successful in the kea (keyphrase extraction algorithm) work derived from turney’s seminal paper.
#
# in the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number. ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases. this is the technique used by turney with c4.5 decision trees. hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#
# once examples and features are created, we need a way to learn to predict keyphrases. virtually any supervised learning algorithm could be used, such as decision trees, naive bayes, and rule induction. in the case of turney's genex algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm. the extractor follows a series of heuristics to identify keyphrases. the genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#
# unsupervised approach: textrank
# another keyphrase extraction algorithm is textrank. while supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data. many documents with known keyphrases are needed. furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of turney's results demonstrate. unsupervised keyphrase extraction removes the need for training data. it approaches the problem from a different angle. instead of trying to learn explicit features that characterize keyphrases, the textrank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that pagerank selects important web pages. recall this is based on the notion of "prestige" or "recommendation" from social networks. in this way, textrank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. thus the algorithm is easily portable to new domains and languages.
#
# textrank is a general purpose graph-based ranking algorithm for nlp. essentially, it runs pagerank on a graph specially designed for a particular nlp task. for keyphrase extraction, it builds a graph using some set of text units as vertices. edges are based on some measure of semantic or lexical similarity between the text unit vertices. unlike pagerank, the edges are typically undirected and can be weighted to reflect a degree of similarity. once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
# the vertices should correspond to what we want to rank. potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc. however, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases. this has a nice side effect of allowing us to produce keyphrases of arbitrary length. for example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. note that the unigrams placed in the graph can be filtered by part of speech. the authors found that adjectives and nouns were the best to include. thus, some linguistic knowledge comes into play in this step.
#
# edges are created based on word co-occurrence in this application of textrank. two vertices are connected by an edge if the unigrams appear within a window of size n in the original text. n is typically around 2–10. thus, "natural" and "language" might be linked in a text about nlp. "natural" and "processing" would also be linked because they would both appear in the same string of n words. these edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
# since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases. the technique chosen is to set a count t to be a user-specified fraction of the total number of vertices in the graph. then the top t vertices/unigrams are selected based on their stationary probabilities. a post- processing step is then applied to merge adjacent instances of these t unigrams. as a result, potentially more or less than t final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
# it is not initially clear why applying pagerank to a co-occurrence graph would produce useful keyphrases. one way to think about it is the following. a word that appears multiple times throughout a text may have many different co-occurring neighbors. for example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. thus, the "learning" vertex would be a central "hub" that connects to these other modifying words. running pagerank/textrank on the graph is likely to rank "learning" highly. similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification". if "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised". if it ends up with a high rank, it will be selected as one of the top t unigrams, along with "learning" and probably "classification". in the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
# in short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts. a random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters. this is similar to densely connected web pages getting ranked highly by pagerank. this approach has also been used in document summarization, considered below.
#
# document summarization
# like keyphrase extraction, document summarization aims to identify the essence of a text. the only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
# before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. the most common way is using the so-called rouge (recall-oriented understudy for gisting evaluation) measure. this is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. it is recall-based to encourage systems to include all the important topics in the text. recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching. for example, rouge-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
# if there are multiple references, the rouge-1 scores are averaged. because rouge is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. high-order n-gram rouge measures try to judge fluency to some degree. note that rouge is similar to the bleu measure for machine translation, but bleu is precision- based, because translation systems favor accuracy.
#
# a promising line in document summarization is adaptive document/text summarization.[8] the idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. first summarizes that perform adaptive summarization have been created.[9]
#
# supervised learning approaches
# supervised text summarization is very much like supervised keyphrase extraction. basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc. the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". this is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient. the sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. note, however, that these natural summaries can still be used for evaluation purposes, since rouge-1 only cares about unigrams.
#
# maximum entropy-based summarization
# during the duc 2001 and 2002 evaluation workshops, tno developed a sentence extraction system for multi-document summarization in the news domain. the system was based on a hybrid system using a naive bayes classifier and statistical language models for modeling salience. although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (me) classifier for the meeting summarization task, as me is known to be robust against feature dependencies. maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
# textrank and lexrank
# the unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. then the sentences can be ranked with regard to their similarity to this centroid sentence.
#
# a more principled way to estimate sentence importance is using random walks and eigenvector centrality. lexrank[10] is an algorithm essentially identical to textrank, and both use this approach for document summarization. the two methods were developed by different groups at the same time, and lexrank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other nlp ranking task.
#
# in both lexrank and textrank, a graph is constructed by creating a vertex for each sentence in the document.
#
# the edges between sentences are based on some form of semantic similarity or content overlap. while lexrank uses cosine similarity of tf-idf vectors, textrank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). the lexrank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score. textrank uses continuous similarity scores as weights.
#
# in both algorithms, the sentences are ranked by applying pagerank to the resulting graph. a summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
# it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. in this case, some training documents might be needed, though the textrank results show the additional features are not absolutely necessary.
#
# another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization. the task remains the same in both cases—only the number of sentences to choose from has grown. however, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary. imagine you have a cluster of news articles on a particular event, and you want to produce one summary. each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary. to address this issue, lexrank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. the method used is called cross-sentence information subsumption (csis).
#
# these methods work based on the idea that sentences "recommend" other similar sentences to the reader. thus, if one sentence is very similar to many others, it will likely be a sentence of great importance. the importance of this sentence also stems from the importance of the sentences "recommending" it. thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences. this makes intuitive sense and allows the algorithms to be applied to any arbitrary new text. the methods are domain-independent and easily portable. one could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain. however, the unsupervised "recommendation"-based approach applies to any domain.
#
# multi-document summarization
# main article: multi-document summarization
# multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents. in such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. multi-document summarization may also be done in response to a question.[11]
#
# multi-document summarization creates information reports that are both concise and comprehensive. with different opinions being put together and outlined, every topic is described from multiple perspectives within a single document. while the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#
# incorporating diversity
# multi-document extractive summarization faces a problem of potential redundancy. ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another). lexrank deals with diversity as a heuristic final stage using csis, and other systems have used similar methods, such as maximal marginal relevance (mmr),[12] in trying to eliminate redundancy in information retrieval results. there is a general purpose graph-based ranking algorithm like page/lex/textrank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing markov chain random walks. (an absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.) the algorithm is called grasshopper.[13] in addition to explicitly promoting diversity during the ranking process, grasshopper incorporates a prior ranking (based on sentence position in the case of summarization).
#
# the state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. these methods have achieved the state of the art results for document summarization corpora, duc 04 - 07.[14] similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
# a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. this tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
# submodular functions as generic tools for summarization
# the idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. submodular functions naturally model notions of coverage, information, representation and diversity. moreover, several important combinatorial optimization problems occur as special instances of submodular optimization. for example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. the set cover function attempts to find a subset of objects which cover a given set of concepts. for example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. this is an instance of set cover. similarly, the facility location problem is a special case of submodular functions. the facility location function also naturally models coverage and diversity. another example of a submodular optimization problem is using a determinantal point process to model diversity. similarly, the maximum-marginal-relevance procedure can also be seen as an instance of submodular optimization. all these important models encouraging coverage, diversity and information are all submodular. moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular. hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
# while submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization. for example, a simple greedy algorithm admits a constant factor guarantee.[16] moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
# submodular functions have achieved state-of-the-art for almost all summarization problems. for example, work by lin and bilmes, 2012[17] shows that submodular functions achieve the best results to date on duc-04, duc-05, duc-06 and duc-07 systems for document summarization. similarly, work by lin and bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. this was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
# submodular functions have also been used for other summarization tasks. tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. similarly, bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies. submodular functions have also successfully been used for summarizing machine learning datasets

# %%
word_freq = {}
for word in document:
    if word.text not in stop:
        if word.text not in punctuation:
            if word.text not in word_freq.keys():
                word_freq[word.text] = 1
            else:
                word_freq[word.text] += 1

# %%
word_freq
# Out:
# {'broadly': 1,
#  'types': 1,
#  'extractive': 3,
#  'summarization': 60,
#  'tasks': 2,
#  'depending': 3,
#  'program': 1,
#  'focuses': 2,
#  'generic': 4,
#  'obtaining': 1,
#  'summary': 27,
#  'abstract': 2,
#  'collection': 5,
#  'documents': 14,
#  'sets': 1,
#  'images': 4,
#  'videos': 3,
#  'news': 11,
#  'stories': 1,
#  'etc': 5,
#  'second': 2,
#  'query': 6,
#  'relevant': 4,
#  'called': 6,
#  'based': 21,
#  'summarizes': 3,
#  'objects': 3,
#  'specific': 3,
#  'systems': 8,
#  'able': 4,
#  'create': 5,
#  'text': 36,
#  'summaries': 10,
#  'machine': 6,
#  'generated': 4,
#  'user': 6,
#  'needs': 1,
#  '\n\n': 41,
#  'example': 20,
#  'problem': 9,
#  'document': 38,
#  'attempts': 2,
#  'automatically': 5,
#  'produce': 11,
#  'given': 6,
#  'interested': 1,
#  'generating': 6,
#  'single': 4,
#  'source': 3,
#  'use': 6,
#  'multiple': 7,
#  'cluster': 3,
#  'articles': 6,
#  'topic': 5,
#  'multi': 16,
#  'related': 4,
#  'application': 4,
#  'summarizing': 4,
#  'imagine': 3,
#  'system': 15,
#  'pulls': 1,
#  'web': 3,
#  'concisely': 1,
#  'represents': 1,
#  'latest': 1,
#  'image': 3,
#  'automatic': 5,
#  'consists': 1,
#  'selecting': 3,
#  'representative': 2,
#  'set': 17,
#  'larger': 4,
#  'images.[4': 1,
#  'context': 1,
#  'useful': 3,
#  'results': 10,
#  'exploration': 1,
#  'video': 2,
#  'domain': 10,
#  'creates': 2,
#  'trailer': 1,
#  'long': 2,
#  'applications': 3,
#  'consumer': 1,
#  'personal': 1,
#  'want': 5,
#  'skip': 1,
#  'boring': 2,
#  'repetitive': 1,
#  'actions': 1,
#  'similarly': 6,
#  'surveillance': 1,
#  'extract': 3,
#  'important': 10,
#  'suspicious': 1,
#  'activity': 1,
#  'ignoring': 1,
#  'redundant': 2,
#  'frames': 1,
#  'captured': 1,
#  'high': 4,
#  'level': 1,
#  'algorithms': 7,
#  'try': 2,
#  'find': 3,
#  'subsets': 1,
#  'like': 10,
#  'sentences': 30,
#  'cover': 7,
#  'information': 15,
#  'entire': 1,
#  'core': 1,
#  'model': 9,
#  'notions': 2,
#  'diversity': 10,
#  'coverage': 5,
#  'representativeness': 1,
#  'techniques': 2,
#  'additionally': 1,
#  'relevance': 5,
#  'naturally': 3,
#  'problems': 6,
#  'textrank': 17,
#  'pagerank': 8,
#  'submodular': 26,
#  'function': 9,
#  'determinantal': 3,
#  'point': 3,
#  'process': 4,
#  'maximal': 2,
#  'marginal': 3,
#  'mmr': 1,
#  'keyphrase': 20,
#  'extraction': 16,
#  'task': 5,
#  'following': 3,
#  'piece': 2,
#  'journal': 2,
#  'article': 4,
#  'list': 2,
#  'keywords': 2,
#  'key[phrase]s': 1,
#  'capture': 1,
#  'primary': 1,
#  'topics': 2,
#  'discussed': 4,
#  'text.[5': 1,
#  'case': 9,
#  'research': 1,
#  'authors': 3,
#  'provide': 2,
#  'manually': 2,
#  'assigned': 2,
#  'lacks': 1,
#  'pre': 1,
#  'existing': 3,
#  'keyphrases': 31,
#  'rarely': 1,
#  'attached': 1,
#  'number': 10,
#  'consider': 1,
#  'army': 2,
#  'corps': 2,
#  'engineers': 2,
#  'rushing': 1,
#  'meet': 1,
#  'president': 2,
#  'bush': 2,
#  'promise': 1,
#  'protect': 1,
#  'new': 5,
#  'orleans': 2,
#  'start': 1,
#  '2006': 1,
#  'hurricane': 1,
#  'season': 1,
#  'installed': 1,
#  'defective': 2,
#  'flood': 2,
#  'control': 2,
#  'pumps': 2,
#  'year': 1,
#  'despite': 1,
#  'warnings': 1,
#  'expert': 1,
#  'equipment': 1,
#  'fail': 1,
#  'storm': 1,
#  'according': 1,
#  'obtained': 3,
#  'associated': 1,
#  'press': 1,
#  'extractor': 2,
#  'select': 3,
#  'pulled': 1,
#  'directly': 1,
#  'contrast': 1,
#  'abstractive': 1,
#  'internalize': 1,
#  'content': 4,
#  'generate': 2,
#  'appear': 8,
#  'closely': 1,
#  'resemble': 1,
#  'human': 5,
#  'political': 1,
#  'negligence': 1,
#  'inadequate': 1,
#  'protection': 1,
#  'floods': 1,
#  'abstraction': 1,
#  'requires': 1,
#  'deep': 1,
#  'understanding': 1,
#  'makes': 2,
#  'difficult': 2,
#  'computer': 1,
#  'enable': 1,
#  'browsing': 1,
#  'providing': 1,
#  'short': 2,
#  'improve': 1,
#  'retrieval': 2,
#  'search': 3,
#  'reliable': 1,
#  'hits': 1,
#  'employed': 1,
#  'index': 1,
#  'entries': 1,
#  'large': 5,
#  'corpus': 2,
#  'different': 7,
#  'literature': 1,
#  'definition': 1,
#  'key': 2,
#  'terms': 3,
#  'words': 9,
#  'phrases': 5,
#  'keyword': 1,
#  'highly': 6,
#  'theme': 1,
#  'supervised': 18,
#  'learning': 13,
#  'approaches': 4,
#  'beginning': 1,
#  'work': 5,
#  'turney,[6': 1,
#  'researchers': 2,
#  'approached': 1,
#  'construct': 1,
#  'unigram': 4,
#  'bigram': 3,
#  'trigram': 3,
#  'found': 3,
#  'units': 3,
#  'possible': 2,
#  'compute': 1,
#  'features': 15,
#  'describing': 1,
#  'e.g.': 2,
#  'phrase': 3,
#  'begin': 1,
#  'upper': 1,
#  'letter': 1,
#  'assume': 1,
#  'known': 10,
#  'available': 1,
#  'training': 12,
#  'assign': 3,
#  'positive': 2,
#  'negative': 2,
#  'labels': 2,
#  'examples': 9,
#  'learn': 7,
#  'classifier': 5,
#  'discriminate': 2,
#  'classifiers': 2,
#  'binary': 3,
#  'classification': 7,
#  'test': 4,
#  'probability': 2,
#  'instance': 3,
#  'rule': 2,
#  'says': 1,
#  'initial': 1,
#  'capital': 1,
#  'letters': 1,
#  'likely': 5,
#  'learner': 2,
#  'manner': 2,
#  'apply': 2,
#  'generation': 1,
#  'strategy': 1,
#  'run': 2,
#  'determine': 4,
#  'looking': 1,
#  'decisions': 1,
#  'probabilities': 4,
#  'returned': 1,
#  'learned': 1,
#  'threshold': 4,
#  'extractors': 1,
#  'generally': 1,
#  'evaluated': 2,
#  'precision': 3,
#  'recall': 8,
#  'measures': 4,
#  'proposed': 3,
#  'actually': 1,
#  'correct': 1,
#  'true': 1,
#  'combined': 3,
#  'f': 2,
#  'score': 3,
#  'harmonic': 1,
#  'mean': 2,
#  '2pr/(p': 1,
#  'r': 1,
#  'matches': 1,
#  'checked': 1,
#  'stemming': 1,
#  'applying': 4,
#  'normalization': 1,
#  'designing': 1,
#  'involves': 2,
#  'deciding': 1,
#  'choices': 1,
#  'unsupervised': 7,
#  'choice': 1,
#  'exactly': 2,
#  'turney': 6,
#  'unigrams': 13,
#  'bigrams': 2,
#  'trigrams': 2,
#  'intervening': 1,
#  'punctuation': 1,
#  'removing': 1,
#  'stopwords': 1,
#  'hulth': 3,
#  'showed': 1,
#  'improvement': 1,
#  'sequences': 1,
#  'tokens': 1,
#  'match': 2,
#  'certain': 1,
#  'patterns': 1,
#  'speech': 2,
#  'tags': 1,
#  'ideally': 2,
#  'mechanism': 1,
#  'produces': 1,
#  'labeled': 2,
#  'candidates': 2,
#  'containing': 1,
#  'suffer': 1,
#  'lead': 1,
#  'low': 1,
#  'need': 8,
#  'describe': 1,
#  'informative': 1,
#  'allow': 1,
#  'algorithm': 16,
#  'non-': 1,
#  'typically': 5,
#  'involve': 1,
#  'term': 1,
#  'frequencies': 1,
#  'times': 2,
#  'appears': 3,
#  'current': 1,
#  'length': 5,
#  'relative': 1,
#  'position': 5,
#  'occurrence': 4,
#  'boolean': 1,
#  'syntactic': 1,
#  'contains': 2,
#  'caps': 1,
#  'paper': 3,
#  '12': 1,
#  'uses': 4,
#  'reduced': 1,
#  'successful': 1,
#  'kea': 1,
#  'derived': 1,
#  'seminal': 1,
#  'end': 3,
#  'return': 1,
#  'way': 10,
#  'limit': 2,
#  'ensemble': 1,
#  'methods': 9,
#  'i.e.': 5,
#  'votes': 1,
#  'numeric': 1,
#  'scores': 3,
#  'thresholded': 1,
#  'provided': 1,
#  'technique': 2,
#  'c4.5': 1,
#  'decision': 2,
#  'trees': 2,
#  'implicitly': 1,
#  'determines': 2,
#  'appropriate': 1,
#  'created': 3,
#  'predict': 1,
#  'virtually': 1,
#  'naive': 2,
#  'bayes': 2,
#  'induction': 1,
#  'genex': 1,
#  'genetic': 2,
#  'parameters': 3,
#  'follows': 1,
#  'series': 1,
#  'heuristics': 2,
#  'identify': 2,
#  'optimizes': 1,
#  'respect': 2,
#  'performance': 1,
#  'approach': 5,
#  'nice': 2,
#  'properties': 2,
#  'interpretable': 1,
#  'rules': 1,
#  'characterize': 2,
#  'require': 1,
#  'data': 4,
#  'needed': 3,
#  'furthermore': 1,
#  'tends': 1,
#  'customize': 1,
#  'resulting': 4,
#  'necessarily': 2,
#  'portable': 3,
#  'demonstrate': 1,
#  'removes': 1,
#  'angle': 1,
#  'instead': 2,
#  'trying': 2,
#  'explicit': 1,
#  'algorithm[7': 1,
#  'exploits': 1,
#  'structure': 1,
#  'central': 3,
#  'selects': 1,
#  'pages': 2,
#  'notion': 2,
#  'prestige': 1,
#  'recommendation': 1,
#  'social': 1,
#  'networks': 1,
#  'rely': 1,
#  'previous': 1,
#  'arbitrary': 3,
#  'output': 1,
#  'simply': 4,
#  'intrinsic': 1,
#  'easily': 3,
#  'domains': 1,
#  'languages': 1,
#  'general': 3,
#  'purpose': 2,
#  'graph': 15,
#  'ranking': 7,
#  'nlp': 4,
#  'essentially': 2,
#  'runs': 1,
#  'specially': 1,
#  'designed': 1,
#  'particular': 2,
#  'builds': 2,
#  'vertices': 8,
#  'edges': 7,
#  'measure': 5,
#  'semantic': 2,
#  'lexical': 1,
#  'similarity': 8,
#  'unit': 1,
#  'unlike': 1,
#  'undirected': 1,
#  'weighted': 1,
#  'reflect': 1,
#  'degree': 2,
#  'constructed': 2,
#  'form': 3,
#  'stochastic': 1,
#  'matrix': 1,
#  'damping': 1,
#  'factor': 2,
#  'random': 7,
#  'surfer': 1,
#  'finding': 2,
#  'eigenvector': 2,
#  'corresponding': 1,
#  'eigenvalue': 1,
#  '1': 1,
#  'stationary': 4,
#  'distribution': 2,
#  'walk': 5,
#  'correspond': 1,
#  'rank': 6,
#  'potentially': 2,
#  'similar': 13,
#  'vertex': 3,
#  'small': 1,
#  'decide': 1,
#  'individual': 3,
#  'step': 7,
#  'include': 5,
#  'merges': 1,
#  'ranked': 5,
#  'adjacent': 2,
#  'word': 5,
#  'effect': 1,
#  'allowing': 1,
#  'advanced': 1,
#  'natural': 4,
#  'language': 3,
#  'processing': 5,
#  'ranks': 2,
#  'look': 1,
#  'original': 6,
#  'consecutively': 1,
#  'final': 4,
#  'note': 3,
#  'placed': 3,
#  'filtered': 1,
#  'adjectives': 1,
#  'nouns': 1,
#  'best': 2,
#  'linguistic': 1,
#  'knowledge': 1,
#  'comes': 1,
#  'play': 1,
#  'co': 5,
#  'connected': 3,
#  'edge': 2,
#  'window': 1,
#  'size': 2,
#  'n': 4,
#  '2–10': 1,
#  'linked': 2,
#  'string': 1,
#  'build': 1,
#  'cohesion': 1,
#  'idea': 4,
#  'near': 1,
#  'meaningful': 1,
#  'recommend': 2,
#  'reader': 2,
#  'method': 3,
#  'limited': 1,
#  'chosen': 1,
#  'count': 3,
#  't': 5,
#  'specified': 2,
#  'fraction': 1,
#  'total': 1,
#  'selected': 2,
#  'post-': 1,
#  'applied': 5,
#  'merge': 1,
#  'instances': 3,
#  'result': 3,
#  'produced': 1,
#  'roughly': 1,
#  'proportional': 1,
#  'initially': 1,
#  'clear': 1,
#  'think': 1,
#  'occurring': 1,
#  'neighbors': 2,
#  'occur': 2,
#  'un': 1,
#  'semi': 1,
#  'hub': 1,
#  'connects': 1,
#  'modifying': 1,
#  'running': 1,
#  'places': 1,
#  'importance': 6,
#  'contribute': 1,
#  'ends': 1,
#  'probably': 2,
#  'post': 2,
#  'contain': 3,
#  'densely': 2,
#  'regions': 1,
#  'contexts': 1,
#  'assigns': 1,
#  'centers': 1,
#  'clusters': 1,
#  'getting': 2,
#  'considered': 2,
#  'aims': 1,
#  'essence': 1,
#  'real': 1,
#  'difference': 1,
#  'dealing': 1,
#  '—': 2,
#  'details': 1,
#  'mention': 1,
#  'common': 2,
#  'rouge': 4,
#  'oriented': 1,
#  'understudy': 1,
#  'gisting': 1,
#  'evaluation': 3,
#  'covers': 1,
#  'present': 2,
#  'references': 2,
#  'encourage': 1,
#  'computed': 2,
#  '4-gram': 1,
#  'matching': 1,
#  'rouge-1': 3,
#  'division': 1,
#  'reference': 3,
#  'averaged': 1,
#  'overlap': 2,
#  'concepts': 3,
#  'coherent': 1,
#  'flow': 1,
#  'sensible': 1,
#  'order': 2,
#  'gram': 1,
#  'judge': 1,
#  'fluency': 1,
#  'bleu': 2,
#  'translation': 2,
#  'precision-': 1,
#  'favor': 1,
#  'accuracy': 1,
#  'promising': 1,
#  'line': 1,
#  'adaptive': 3,
#  'summarization.[8': 1,
#  'preliminary': 1,
#  'recognition': 1,
#  'genre': 2,
#  'subsequent': 1,
#  'optimized': 1,
#  'perform': 1,
#  'created.[9': 1,
#  'basically': 1,
#  'good': 2,
#  'inclusion': 1,
#  'sentence': 15,
#  'main': 3,
#  'difficulty': 1,
#  'extracting': 1,
#  'people': 1,
#  'abstracts': 1,
#  'usually': 1,
#  'sufficient': 1,
#  'purposes': 1,
#  'cares': 1,
#  'maximum': 4,
#  'entropy': 3,
#  'duc': 2,
#  '2001': 1,
#  '2002': 1,
#  'workshops': 1,
#  'tno': 1,
#  'developed': 3,
#  'hybrid': 1,
#  'statistical': 1,
#  'models': 6,
#  'modeling': 2,
#  'salience': 1,
#  'exhibited': 1,
#  'wanted': 1,
#  'explore': 1,
#  'effectiveness': 1,
#  'meeting': 1,
#  'robust': 1,
#  'feature': 1,
#  'dependencies': 1,
#  'successfully': 2,
#  'broadcast': 1,
#  'lexrank': 10,
#  'spirit': 1,
#  'gets': 1,
#  'issue': 2,
#  'costly': 1,
#  'centroid': 2,
#  'vector': 1,
#  'regard': 1,
#  'principled': 1,
#  'estimate': 1,
#  'walks': 2,
#  'centrality': 2,
#  'lexrank[10': 1,
#  'identical': 1,
#  'groups': 1,
#  'time': 2,
#  'focused': 1,
#  'creating': 1,
#  'cosine': 2,
#  'tf': 1,
#  'idf': 1,
#  'vectors': 1,
#  'normalized': 1,
#  'lengths': 1,
#  'explored': 1,
#  'unweighted': 1,
#  'values': 1,
#  'experimented': 1,
#  'weights': 3,
#  'equal': 1,
#  'continuous': 1,
#  'formed': 1,
#  'combining': 1,
#  'cutoff': 1,
#  'worth': 1,
#  'noting': 1,
#  'described': 2,
#  'mead': 1,
#  'combines': 1,
#  'linear': 1,
#  'combination': 1,
#  'tuned': 1,
#  'additional': 1,
#  'absolutely': 1,
#  'necessary': 1,
#  'distinction': 1,
#  'remains': 1,
#  'cases': 2,
#  'choose': 1,
#  'grown': 1,
#  'greater': 1,
#  'risk': 1,
#  'duplicate': 1,
#  'place': 1,
#  'event': 1,
#  'distinct': 1,
#  'ideas': 2,
#  'address': 1,
#  'applies': 2,
#  'heuristic': 2,
#  'adding': 1,
#  'discards': 1,
#  'ones': 1,
#  'cross': 1,
#  'subsumption': 1,
#  'csis': 2,
#  'great': 1,
#  'stems': 1,
#  'recommending': 1,
#  'turn': 1,
#  'intuitive': 1,
#  'sense': 1,
#  'allows': 2,
#  'independent': 1,
#  'indicating': 1,
#  'vary': 1,
#  'considerably': 1,
#  'biomedical': 1,
#  'recommendation"-based': 1,
#  'procedure': 2,
#  'aimed': 1,
#  'texts': 1,
#  'written': 1,
#  'report': 1,
#  'users': 1,
#  'professional': 1,
#  'consumers': 1,
#  'quickly': 1,
#  'familiarize': 1,
#  'contained': 1,
#  'complementing': 1,
#  'aggregators': 1,
#  'performing': 1,
#  'road': 1,
#  'coping': 1,
#  'overload': 1,
#  'response': 1,
#  'question.[11': 1,
#  'reports': 1,
#  'concise': 1,
#  'comprehensive': 2,
#  'opinions': 1,
#  'outlined': 1,
#  'perspectives': 1,
#  'goal': 1,
#  'brief': 1,
#  'simplify': 1,
#  'cut': 1,
#  'pointing': 1,
#  'required': 2,
#  'limiting': 1,
#  'accessing': 1,
#  'files': 1,
#  'refinement': 1,
#  'extracted': 1,
#  'sources': 1,
#  'algorithmically': 1,
#  'editorial': 1,
#  'touch': 1,
#  'subjective': 1,
#  'intervention': 1,
#  'making': 1,
#  'completely': 1,
#  'unbiased.[dubious': 1,
#  '–': 1,
#  'discuss': 1,
#  'incorporating': 1,
#  'faces': 1,
#  'potential': 1,
#  'redundancy': 3,
#  'diverse': 1,
#  'differ': 1,
#  'deals': 1,
#  'stage': 1,
#  'mmr),[12': 1,
#  'eliminate': 1,
#  'page': 1,
#  'lex': 1,
#  'handles': 1,
#  'unified': 1,
#  'mathematical': 1,
#  'framework': 1,
#  'absorbing': 3,
#  'markov': 1,
#  'chain': 1,
#  'standard': 1,
#  'states': 2,
#  'act': 1,
#  'black': 1,
#  'holes': 1,
#  'cause': 1,
#  'abruptly': 1,
#  'state': 5,
#  'grasshopper.[13': 1,
#  'addition': 1,
#  'explicitly': 1,
#  'promoting': 1,
#  'grasshopper': 1,
#  'incorporates': 1,
#  'prior': 1,
#  'art': 4,
#  'mixtures': 2,
#  'functions': 15,
#  'achieved': 3,
#  'corpora': 1,
#  '04': 1,
#  '07.[14': 1,
#  'processes': 1,
#  'special': 4,
#  'duc-04.[15': 1,
#  'lingual': 1,
#  'avoids': 1,
#  'works': 2,
#  'simplifying': 1,
#  'ideograms': 3,
#  'represent': 2,
#  'meaning': 2,
#  'evaluates': 1,
#  'qualitatively': 1,
#  'comparing': 1,
#  'shape': 1,
#  'said': 1,
#  'recently': 2,
#  'tool': 2,
#  'frequency': 1,
#  'preprocessing': 1,
#  'kind': 1,
#  'supplied': 1,
#  'equivalence': 1,
#  'equivalent': 1,
#  'desired': 1,
#  'tools': 1,
#  'emerged': 1,
#  'powerful': 1,
#  'representation': 1,
#  'combinatorial': 1,
#  'optimization': 6,
#  'subset': 1,
#  'facility': 2,
#  'location': 2,
#  'seen': 1,
#  'encouraging': 1,
#  'efficiently': 1,
#  'combine': 1,
#  'supervision': 1,
#  'right': 2,
#  'fitting': 1,
#  'admit': 1,
#  'efficient': 1,
#  'simple': 2,
#  'greedy': 2,
#  'admits': 1,
#  'constant': 1,
#  'guarantee.[16': 1,
#  'extremely': 1,
#  'implement': 1,
#  'scale': 1,
#  'datasets': 2,
#  'lin': 2,
#  'bilmes': 2,
#  '2012[17': 1,
#  'shows': 2,
#  'achieve': 2,
#  'date': 1,
#  'duc-04': 1,
#  'duc-05': 1,
#  'duc-06': 1,
#  'duc-07': 1,
#  '2011,[18': 1,
#  'breakthrough': 1,
#  'establishing': 1,
#  'problems.[citation': 1,
#  'tschiatschek': 1,
#  'et': 2,
#  'al': 2,
#  '2014': 1,
#  'show[19': 1,
#  'bairi': 1,
#  '2015[20': 1,
#  'utility': 1,
#  'hierarchies': 1}

# %%
max_freq = max(word_freq.values())
max_freq
# Out:
# 60

# %%
for word in word_freq.keys():
    word_freq[word] = word_freq[word]/max_freq
word_freq
# Out:
# {'broadly': 0.016666666666666666,
#  'types': 0.016666666666666666,
#  'extractive': 0.05,
#  'summarization': 1.0,
#  'tasks': 0.03333333333333333,
#  'depending': 0.05,
#  'program': 0.016666666666666666,
#  'focuses': 0.03333333333333333,
#  'generic': 0.06666666666666667,
#  'obtaining': 0.016666666666666666,
#  'summary': 0.45,
#  'abstract': 0.03333333333333333,
#  'collection': 0.08333333333333333,
#  'documents': 0.23333333333333334,
#  'sets': 0.016666666666666666,
#  'images': 0.06666666666666667,
#  'videos': 0.05,
#  'news': 0.18333333333333332,
#  'stories': 0.016666666666666666,
#  'etc': 0.08333333333333333,
#  'second': 0.03333333333333333,
#  'query': 0.1,
#  'relevant': 0.06666666666666667,
#  'called': 0.1,
#  'based': 0.35,
#  'summarizes': 0.05,
#  'objects': 0.05,
#  'specific': 0.05,
#  'systems': 0.13333333333333333,
#  'able': 0.06666666666666667,
#  'create': 0.08333333333333333,
#  'text': 0.6,
#  'summaries': 0.16666666666666666,
#  'machine': 0.1,
#  'generated': 0.06666666666666667,
#  'user': 0.1,
#  'needs': 0.016666666666666666,
#  '\n\n': 0.6833333333333333,
#  'example': 0.3333333333333333,
#  'problem': 0.15,
#  'document': 0.6333333333333333,
#  'attempts': 0.03333333333333333,
#  'automatically': 0.08333333333333333,
#  'produce': 0.18333333333333332,
#  'given': 0.1,
#  'interested': 0.016666666666666666,
#  'generating': 0.1,
#  'single': 0.06666666666666667,
#  'source': 0.05,
#  'use': 0.1,
#  'multiple': 0.11666666666666667,
#  'cluster': 0.05,
#  'articles': 0.1,
#  'topic': 0.08333333333333333,
#  'multi': 0.26666666666666666,
#  'related': 0.06666666666666667,
#  'application': 0.06666666666666667,
#  'summarizing': 0.06666666666666667,
#  'imagine': 0.05,
#  'system': 0.25,
#  'pulls': 0.016666666666666666,
#  'web': 0.05,
#  'concisely': 0.016666666666666666,
#  'represents': 0.016666666666666666,
#  'latest': 0.016666666666666666,
#  'image': 0.05,
#  'automatic': 0.08333333333333333,
#  'consists': 0.016666666666666666,
#  'selecting': 0.05,
#  'representative': 0.03333333333333333,
#  'set': 0.2833333333333333,
#  'larger': 0.06666666666666667,
#  'images.[4': 0.016666666666666666,
#  'context': 0.016666666666666666,
#  'useful': 0.05,
#  'results': 0.16666666666666666,
#  'exploration': 0.016666666666666666,
#  'video': 0.03333333333333333,
#  'domain': 0.16666666666666666,
#  'creates': 0.03333333333333333,
#  'trailer': 0.016666666666666666,
#  'long': 0.03333333333333333,
#  'applications': 0.05,
#  'consumer': 0.016666666666666666,
#  'personal': 0.016666666666666666,
#  'want': 0.08333333333333333,
#  'skip': 0.016666666666666666,
#  'boring': 0.03333333333333333,
#  'repetitive': 0.016666666666666666,
#  'actions': 0.016666666666666666,
#  'similarly': 0.1,
#  'surveillance': 0.016666666666666666,
#  'extract': 0.05,
#  'important': 0.16666666666666666,
#  'suspicious': 0.016666666666666666,
#  'activity': 0.016666666666666666,
#  'ignoring': 0.016666666666666666,
#  'redundant': 0.03333333333333333,
#  'frames': 0.016666666666666666,
#  'captured': 0.016666666666666666,
#  'high': 0.06666666666666667,
#  'level': 0.016666666666666666,
#  'algorithms': 0.11666666666666667,
#  'try': 0.03333333333333333,
#  'find': 0.05,
#  'subsets': 0.016666666666666666,
#  'like': 0.16666666666666666,
#  'sentences': 0.5,
#  'cover': 0.11666666666666667,
#  'information': 0.25,
#  'entire': 0.016666666666666666,
#  'core': 0.016666666666666666,
#  'model': 0.15,
#  'notions': 0.03333333333333333,
#  'diversity': 0.16666666666666666,
#  'coverage': 0.08333333333333333,
#  'representativeness': 0.016666666666666666,
#  'techniques': 0.03333333333333333,
#  'additionally': 0.016666666666666666,
#  'relevance': 0.08333333333333333,
#  'naturally': 0.05,
#  'problems': 0.1,
#  'textrank': 0.2833333333333333,
#  'pagerank': 0.13333333333333333,
#  'submodular': 0.43333333333333335,
#  'function': 0.15,
#  'determinantal': 0.05,
#  'point': 0.05,
#  'process': 0.06666666666666667,
#  'maximal': 0.03333333333333333,
#  'marginal': 0.05,
#  'mmr': 0.016666666666666666,
#  'keyphrase': 0.3333333333333333,
#  'extraction': 0.26666666666666666,
#  'task': 0.08333333333333333,
#  'following': 0.05,
#  'piece': 0.03333333333333333,
#  'journal': 0.03333333333333333,
#  'article': 0.06666666666666667,
#  'list': 0.03333333333333333,
#  'keywords': 0.03333333333333333,
#  'key[phrase]s': 0.016666666666666666,
#  'capture': 0.016666666666666666,
#  'primary': 0.016666666666666666,
#  'topics': 0.03333333333333333,
#  'discussed': 0.06666666666666667,
#  'text.[5': 0.016666666666666666,
#  'case': 0.15,
#  'research': 0.016666666666666666,
#  'authors': 0.05,
#  'provide': 0.03333333333333333,
#  'manually': 0.03333333333333333,
#  'assigned': 0.03333333333333333,
#  'lacks': 0.016666666666666666,
#  'pre': 0.016666666666666666,
#  'existing': 0.05,
#  'keyphrases': 0.5166666666666667,
#  'rarely': 0.016666666666666666,
#  'attached': 0.016666666666666666,
#  'number': 0.16666666666666666,
#  'consider': 0.016666666666666666,
#  'army': 0.03333333333333333,
#  'corps': 0.03333333333333333,
#  'engineers': 0.03333333333333333,
#  'rushing': 0.016666666666666666,
#  'meet': 0.016666666666666666,
#  'president': 0.03333333333333333,
#  'bush': 0.03333333333333333,
#  'promise': 0.016666666666666666,
#  'protect': 0.016666666666666666,
#  'new': 0.08333333333333333,
#  'orleans': 0.03333333333333333,
#  'start': 0.016666666666666666,
#  '2006': 0.016666666666666666,
#  'hurricane': 0.016666666666666666,
#  'season': 0.016666666666666666,
#  'installed': 0.016666666666666666,
#  'defective': 0.03333333333333333,
#  'flood': 0.03333333333333333,
#  'control': 0.03333333333333333,
#  'pumps': 0.03333333333333333,
#  'year': 0.016666666666666666,
#  'despite': 0.016666666666666666,
#  'warnings': 0.016666666666666666,
#  'expert': 0.016666666666666666,
#  'equipment': 0.016666666666666666,
#  'fail': 0.016666666666666666,
#  'storm': 0.016666666666666666,
#  'according': 0.016666666666666666,
#  'obtained': 0.05,
#  'associated': 0.016666666666666666,
#  'press': 0.016666666666666666,
#  'extractor': 0.03333333333333333,
#  'select': 0.05,
#  'pulled': 0.016666666666666666,
#  'directly': 0.016666666666666666,
#  'contrast': 0.016666666666666666,
#  'abstractive': 0.016666666666666666,
#  'internalize': 0.016666666666666666,
#  'content': 0.06666666666666667,
#  'generate': 0.03333333333333333,
#  'appear': 0.13333333333333333,
#  'closely': 0.016666666666666666,
#  'resemble': 0.016666666666666666,
#  'human': 0.08333333333333333,
#  'political': 0.016666666666666666,
#  'negligence': 0.016666666666666666,
#  'inadequate': 0.016666666666666666,
#  'protection': 0.016666666666666666,
#  'floods': 0.016666666666666666,
#  'abstraction': 0.016666666666666666,
#  'requires': 0.016666666666666666,
#  'deep': 0.016666666666666666,
#  'understanding': 0.016666666666666666,
#  'makes': 0.03333333333333333,
#  'difficult': 0.03333333333333333,
#  'computer': 0.016666666666666666,
#  'enable': 0.016666666666666666,
#  'browsing': 0.016666666666666666,
#  'providing': 0.016666666666666666,
#  'short': 0.03333333333333333,
#  'improve': 0.016666666666666666,
#  'retrieval': 0.03333333333333333,
#  'search': 0.05,
#  'reliable': 0.016666666666666666,
#  'hits': 0.016666666666666666,
#  'employed': 0.016666666666666666,
#  'index': 0.016666666666666666,
#  'entries': 0.016666666666666666,
#  'large': 0.08333333333333333,
#  'corpus': 0.03333333333333333,
#  'different': 0.11666666666666667,
#  'literature': 0.016666666666666666,
#  'definition': 0.016666666666666666,
#  'key': 0.03333333333333333,
#  'terms': 0.05,
#  'words': 0.15,
#  'phrases': 0.08333333333333333,
#  'keyword': 0.016666666666666666,
#  'highly': 0.1,
#  'theme': 0.016666666666666666,
#  'supervised': 0.3,
#  'learning': 0.21666666666666667,
#  'approaches': 0.06666666666666667,
#  'beginning': 0.016666666666666666,
#  'work': 0.08333333333333333,
#  'turney,[6': 0.016666666666666666,
#  'researchers': 0.03333333333333333,
#  'approached': 0.016666666666666666,
#  'construct': 0.016666666666666666,
#  'unigram': 0.06666666666666667,
#  'bigram': 0.05,
#  'trigram': 0.05,
#  'found': 0.05,
#  'units': 0.05,
#  'possible': 0.03333333333333333,
#  'compute': 0.016666666666666666,
#  'features': 0.25,
#  'describing': 0.016666666666666666,
#  'e.g.': 0.03333333333333333,
#  'phrase': 0.05,
#  'begin': 0.016666666666666666,
#  'upper': 0.016666666666666666,
#  'letter': 0.016666666666666666,
#  'assume': 0.016666666666666666,
#  'known': 0.16666666666666666,
#  'available': 0.016666666666666666,
#  'training': 0.2,
#  'assign': 0.05,
#  'positive': 0.03333333333333333,
#  'negative': 0.03333333333333333,
#  'labels': 0.03333333333333333,
#  'examples': 0.15,
#  'learn': 0.11666666666666667,
#  'classifier': 0.08333333333333333,
#  'discriminate': 0.03333333333333333,
#  'classifiers': 0.03333333333333333,
#  'binary': 0.05,
#  'classification': 0.11666666666666667,
#  'test': 0.06666666666666667,
#  'probability': 0.03333333333333333,
#  'instance': 0.05,
#  'rule': 0.03333333333333333,
#  'says': 0.016666666666666666,
#  'initial': 0.016666666666666666,
#  'capital': 0.016666666666666666,
#  'letters': 0.016666666666666666,
#  'likely': 0.08333333333333333,
#  'learner': 0.03333333333333333,
#  'manner': 0.03333333333333333,
#  'apply': 0.03333333333333333,
#  'generation': 0.016666666666666666,
#  'strategy': 0.016666666666666666,
#  'run': 0.03333333333333333,
#  'determine': 0.06666666666666667,
#  'looking': 0.016666666666666666,
#  'decisions': 0.016666666666666666,
#  'probabilities': 0.06666666666666667,
#  'returned': 0.016666666666666666,
#  'learned': 0.016666666666666666,
#  'threshold': 0.06666666666666667,
#  'extractors': 0.016666666666666666,
#  'generally': 0.016666666666666666,
#  'evaluated': 0.03333333333333333,
#  'precision': 0.05,
#  'recall': 0.13333333333333333,
#  'measures': 0.06666666666666667,
#  'proposed': 0.05,
#  'actually': 0.016666666666666666,
#  'correct': 0.016666666666666666,
#  'true': 0.016666666666666666,
#  'combined': 0.05,
#  'f': 0.03333333333333333,
#  'score': 0.05,
#  'harmonic': 0.016666666666666666,
#  'mean': 0.03333333333333333,
#  '2pr/(p': 0.016666666666666666,
#  'r': 0.016666666666666666,
#  'matches': 0.016666666666666666,
#  'checked': 0.016666666666666666,
#  'stemming': 0.016666666666666666,
#  'applying': 0.06666666666666667,
#  'normalization': 0.016666666666666666,
#  'designing': 0.016666666666666666,
#  'involves': 0.03333333333333333,
#  'deciding': 0.016666666666666666,
#  'choices': 0.016666666666666666,
#  'unsupervised': 0.11666666666666667,
#  'choice': 0.016666666666666666,
#  'exactly': 0.03333333333333333,
#  'turney': 0.1,
#  'unigrams': 0.21666666666666667,
#  'bigrams': 0.03333333333333333,
#  'trigrams': 0.03333333333333333,
#  'intervening': 0.016666666666666666,
#  'punctuation': 0.016666666666666666,
#  'removing': 0.016666666666666666,
#  'stopwords': 0.016666666666666666,
#  'hulth': 0.05,
#  'showed': 0.016666666666666666,
#  'improvement': 0.016666666666666666,
#  'sequences': 0.016666666666666666,
#  'tokens': 0.016666666666666666,
#  'match': 0.03333333333333333,
#  'certain': 0.016666666666666666,
#  'patterns': 0.016666666666666666,
#  'speech': 0.03333333333333333,
#  'tags': 0.016666666666666666,
#  'ideally': 0.03333333333333333,
#  'mechanism': 0.016666666666666666,
#  'produces': 0.016666666666666666,
#  'labeled': 0.03333333333333333,
#  'candidates': 0.03333333333333333,
#  'containing': 0.016666666666666666,
#  'suffer': 0.016666666666666666,
#  'lead': 0.016666666666666666,
#  'low': 0.016666666666666666,
#  'need': 0.13333333333333333,
#  'describe': 0.016666666666666666,
#  'informative': 0.016666666666666666,
#  'allow': 0.016666666666666666,
#  'algorithm': 0.26666666666666666,
#  'non-': 0.016666666666666666,
#  'typically': 0.08333333333333333,
#  'involve': 0.016666666666666666,
#  'term': 0.016666666666666666,
#  'frequencies': 0.016666666666666666,
#  'times': 0.03333333333333333,
#  'appears': 0.05,
#  'current': 0.016666666666666666,
#  'length': 0.08333333333333333,
#  'relative': 0.016666666666666666,
#  'position': 0.08333333333333333,
#  'occurrence': 0.06666666666666667,
#  'boolean': 0.016666666666666666,
#  'syntactic': 0.016666666666666666,
#  'contains': 0.03333333333333333,
#  'caps': 0.016666666666666666,
#  'paper': 0.05,
#  '12': 0.016666666666666666,
#  'uses': 0.06666666666666667,
#  'reduced': 0.016666666666666666,
#  'successful': 0.016666666666666666,
#  'kea': 0.016666666666666666,
#  'derived': 0.016666666666666666,
#  'seminal': 0.016666666666666666,
#  'end': 0.05,
#  'return': 0.016666666666666666,
#  'way': 0.16666666666666666,
#  'limit': 0.03333333333333333,
#  'ensemble': 0.016666666666666666,
#  'methods': 0.15,
#  'i.e.': 0.08333333333333333,
#  'votes': 0.016666666666666666,
#  'numeric': 0.016666666666666666,
#  'scores': 0.05,
#  'thresholded': 0.016666666666666666,
#  'provided': 0.016666666666666666,
#  'technique': 0.03333333333333333,
#  'c4.5': 0.016666666666666666,
#  'decision': 0.03333333333333333,
#  'trees': 0.03333333333333333,
#  'implicitly': 0.016666666666666666,
#  'determines': 0.03333333333333333,
#  'appropriate': 0.016666666666666666,
#  'created': 0.05,
#  'predict': 0.016666666666666666,
#  'virtually': 0.016666666666666666,
#  'naive': 0.03333333333333333,
#  'bayes': 0.03333333333333333,
#  'induction': 0.016666666666666666,
#  'genex': 0.016666666666666666,
#  'genetic': 0.03333333333333333,
#  'parameters': 0.05,
#  'follows': 0.016666666666666666,
#  'series': 0.016666666666666666,
#  'heuristics': 0.03333333333333333,
#  'identify': 0.03333333333333333,
#  'optimizes': 0.016666666666666666,
#  'respect': 0.03333333333333333,
#  'performance': 0.016666666666666666,
#  'approach': 0.08333333333333333,
#  'nice': 0.03333333333333333,
#  'properties': 0.03333333333333333,
#  'interpretable': 0.016666666666666666,
#  'rules': 0.016666666666666666,
#  'characterize': 0.03333333333333333,
#  'require': 0.016666666666666666,
#  'data': 0.06666666666666667,
#  'needed': 0.05,
#  'furthermore': 0.016666666666666666,
#  'tends': 0.016666666666666666,
#  'customize': 0.016666666666666666,
#  'resulting': 0.06666666666666667,
#  'necessarily': 0.03333333333333333,
#  'portable': 0.05,
#  'demonstrate': 0.016666666666666666,
#  'removes': 0.016666666666666666,
#  'angle': 0.016666666666666666,
#  'instead': 0.03333333333333333,
#  'trying': 0.03333333333333333,
#  'explicit': 0.016666666666666666,
#  'algorithm[7': 0.016666666666666666,
#  'exploits': 0.016666666666666666,
#  'structure': 0.016666666666666666,
#  'central': 0.05,
#  'selects': 0.016666666666666666,
#  'pages': 0.03333333333333333,
#  'notion': 0.03333333333333333,
#  'prestige': 0.016666666666666666,
#  'recommendation': 0.016666666666666666,
#  'social': 0.016666666666666666,
#  'networks': 0.016666666666666666,
#  'rely': 0.016666666666666666,
#  'previous': 0.016666666666666666,
#  'arbitrary': 0.05,
#  'output': 0.016666666666666666,
#  'simply': 0.06666666666666667,
#  'intrinsic': 0.016666666666666666,
#  'easily': 0.05,
#  'domains': 0.016666666666666666,
#  'languages': 0.016666666666666666,
#  'general': 0.05,
#  'purpose': 0.03333333333333333,
#  'graph': 0.25,
#  'ranking': 0.11666666666666667,
#  'nlp': 0.06666666666666667,
#  'essentially': 0.03333333333333333,
#  'runs': 0.016666666666666666,
#  'specially': 0.016666666666666666,
#  'designed': 0.016666666666666666,
#  'particular': 0.03333333333333333,
#  'builds': 0.03333333333333333,
#  'vertices': 0.13333333333333333,
#  'edges': 0.11666666666666667,
#  'measure': 0.08333333333333333,
#  'semantic': 0.03333333333333333,
#  'lexical': 0.016666666666666666,
#  'similarity': 0.13333333333333333,
#  'unit': 0.016666666666666666,
#  'unlike': 0.016666666666666666,
#  'undirected': 0.016666666666666666,
#  'weighted': 0.016666666666666666,
#  'reflect': 0.016666666666666666,
#  'degree': 0.03333333333333333,
#  'constructed': 0.03333333333333333,
#  'form': 0.05,
#  'stochastic': 0.016666666666666666,
#  'matrix': 0.016666666666666666,
#  'damping': 0.016666666666666666,
#  'factor': 0.03333333333333333,
#  'random': 0.11666666666666667,
#  'surfer': 0.016666666666666666,
#  'finding': 0.03333333333333333,
#  'eigenvector': 0.03333333333333333,
#  'corresponding': 0.016666666666666666,
#  'eigenvalue': 0.016666666666666666,
#  '1': 0.016666666666666666,
#  'stationary': 0.06666666666666667,
#  'distribution': 0.03333333333333333,
#  'walk': 0.08333333333333333,
#  'correspond': 0.016666666666666666,
#  'rank': 0.1,
#  'potentially': 0.03333333333333333,
#  'similar': 0.21666666666666667,
#  'vertex': 0.05,
#  'small': 0.016666666666666666,
#  'decide': 0.016666666666666666,
#  'individual': 0.05,
#  'step': 0.11666666666666667,
#  'include': 0.08333333333333333,
#  'merges': 0.016666666666666666,
#  'ranked': 0.08333333333333333,
#  'adjacent': 0.03333333333333333,
#  'word': 0.08333333333333333,
#  'effect': 0.016666666666666666,
#  'allowing': 0.016666666666666666,
#  'advanced': 0.016666666666666666,
#  'natural': 0.06666666666666667,
#  'language': 0.05,
#  'processing': 0.08333333333333333,
#  'ranks': 0.03333333333333333,
#  'look': 0.016666666666666666,
#  'original': 0.1,
#  'consecutively': 0.016666666666666666,
#  'final': 0.06666666666666667,
#  'note': 0.05,
#  'placed': 0.05,
#  'filtered': 0.016666666666666666,
#  'adjectives': 0.016666666666666666,
#  'nouns': 0.016666666666666666,
#  'best': 0.03333333333333333,
#  'linguistic': 0.016666666666666666,
#  'knowledge': 0.016666666666666666,
#  'comes': 0.016666666666666666,
#  'play': 0.016666666666666666,
#  'co': 0.08333333333333333,
#  'connected': 0.05,
#  'edge': 0.03333333333333333,
#  'window': 0.016666666666666666,
#  'size': 0.03333333333333333,
#  'n': 0.06666666666666667,
#  '2–10': 0.016666666666666666,
#  'linked': 0.03333333333333333,
#  'string': 0.016666666666666666,
#  'build': 0.016666666666666666,
#  'cohesion': 0.016666666666666666,
#  'idea': 0.06666666666666667,
#  'near': 0.016666666666666666,
#  'meaningful': 0.016666666666666666,
#  'recommend': 0.03333333333333333,
#  'reader': 0.03333333333333333,
#  'method': 0.05,
#  'limited': 0.016666666666666666,
#  'chosen': 0.016666666666666666,
#  'count': 0.05,
#  't': 0.08333333333333333,
#  'specified': 0.03333333333333333,
#  'fraction': 0.016666666666666666,
#  'total': 0.016666666666666666,
#  'selected': 0.03333333333333333,
#  'post-': 0.016666666666666666,
#  'applied': 0.08333333333333333,
#  'merge': 0.016666666666666666,
#  'instances': 0.05,
#  'result': 0.05,
#  'produced': 0.016666666666666666,
#  'roughly': 0.016666666666666666,
#  'proportional': 0.016666666666666666,
#  'initially': 0.016666666666666666,
#  'clear': 0.016666666666666666,
#  'think': 0.016666666666666666,
#  'occurring': 0.016666666666666666,
#  'neighbors': 0.03333333333333333,
#  'occur': 0.03333333333333333,
#  'un': 0.016666666666666666,
#  'semi': 0.016666666666666666,
#  'hub': 0.016666666666666666,
#  'connects': 0.016666666666666666,
#  'modifying': 0.016666666666666666,
#  'running': 0.016666666666666666,
#  'places': 0.016666666666666666,
#  'importance': 0.1,
#  'contribute': 0.016666666666666666,
#  'ends': 0.016666666666666666,
#  'probably': 0.03333333333333333,
#  'post': 0.03333333333333333,
#  'contain': 0.05,
#  'densely': 0.03333333333333333,
#  'regions': 0.016666666666666666,
#  'contexts': 0.016666666666666666,
#  'assigns': 0.016666666666666666,
#  'centers': 0.016666666666666666,
#  'clusters': 0.016666666666666666,
#  'getting': 0.03333333333333333,
#  'considered': 0.03333333333333333,
#  'aims': 0.016666666666666666,
#  'essence': 0.016666666666666666,
#  'real': 0.016666666666666666,
#  'difference': 0.016666666666666666,
#  'dealing': 0.016666666666666666,
#  '—': 0.03333333333333333,
#  'details': 0.016666666666666666,
#  'mention': 0.016666666666666666,
#  'common': 0.03333333333333333,
#  'rouge': 0.06666666666666667,
#  'oriented': 0.016666666666666666,
#  'understudy': 0.016666666666666666,
#  'gisting': 0.016666666666666666,
#  'evaluation': 0.05,
#  'covers': 0.016666666666666666,
#  'present': 0.03333333333333333,
#  'references': 0.03333333333333333,
#  'encourage': 0.016666666666666666,
#  'computed': 0.03333333333333333,
#  '4-gram': 0.016666666666666666,
#  'matching': 0.016666666666666666,
#  'rouge-1': 0.05,
#  'division': 0.016666666666666666,
#  'reference': 0.05,
#  'averaged': 0.016666666666666666,
#  'overlap': 0.03333333333333333,
#  'concepts': 0.05,
#  'coherent': 0.016666666666666666,
#  'flow': 0.016666666666666666,
#  'sensible': 0.016666666666666666,
#  'order': 0.03333333333333333,
#  'gram': 0.016666666666666666,
#  'judge': 0.016666666666666666,
#  'fluency': 0.016666666666666666,
#  'bleu': 0.03333333333333333,
#  'translation': 0.03333333333333333,
#  'precision-': 0.016666666666666666,
#  'favor': 0.016666666666666666,
#  'accuracy': 0.016666666666666666,
#  'promising': 0.016666666666666666,
#  'line': 0.016666666666666666,
#  'adaptive': 0.05,
#  'summarization.[8': 0.016666666666666666,
#  'preliminary': 0.016666666666666666,
#  'recognition': 0.016666666666666666,
#  'genre': 0.03333333333333333,
#  'subsequent': 0.016666666666666666,
#  'optimized': 0.016666666666666666,
#  'perform': 0.016666666666666666,
#  'created.[9': 0.016666666666666666,
#  'basically': 0.016666666666666666,
#  'good': 0.03333333333333333,
#  'inclusion': 0.016666666666666666,
#  'sentence': 0.25,
#  'main': 0.05,
#  'difficulty': 0.016666666666666666,
#  'extracting': 0.016666666666666666,
#  'people': 0.016666666666666666,
#  'abstracts': 0.016666666666666666,
#  'usually': 0.016666666666666666,
#  'sufficient': 0.016666666666666666,
#  'purposes': 0.016666666666666666,
#  'cares': 0.016666666666666666,
#  'maximum': 0.06666666666666667,
#  'entropy': 0.05,
#  'duc': 0.03333333333333333,
#  '2001': 0.016666666666666666,
#  '2002': 0.016666666666666666,
#  'workshops': 0.016666666666666666,
#  'tno': 0.016666666666666666,
#  'developed': 0.05,
#  'hybrid': 0.016666666666666666,
#  'statistical': 0.016666666666666666,
#  'models': 0.1,
#  'modeling': 0.03333333333333333,
#  'salience': 0.016666666666666666,
#  'exhibited': 0.016666666666666666,
#  'wanted': 0.016666666666666666,
#  'explore': 0.016666666666666666,
#  'effectiveness': 0.016666666666666666,
#  'meeting': 0.016666666666666666,
#  'robust': 0.016666666666666666,
#  'feature': 0.016666666666666666,
#  'dependencies': 0.016666666666666666,
#  'successfully': 0.03333333333333333,
#  'broadcast': 0.016666666666666666,
#  'lexrank': 0.16666666666666666,
#  'spirit': 0.016666666666666666,
#  'gets': 0.016666666666666666,
#  'issue': 0.03333333333333333,
#  'costly': 0.016666666666666666,
#  'centroid': 0.03333333333333333,
#  'vector': 0.016666666666666666,
#  'regard': 0.016666666666666666,
#  'principled': 0.016666666666666666,
#  'estimate': 0.016666666666666666,
#  'walks': 0.03333333333333333,
#  'centrality': 0.03333333333333333,
#  'lexrank[10': 0.016666666666666666,
#  'identical': 0.016666666666666666,
#  'groups': 0.016666666666666666,
#  'time': 0.03333333333333333,
#  'focused': 0.016666666666666666,
#  'creating': 0.016666666666666666,
#  'cosine': 0.03333333333333333,
#  'tf': 0.016666666666666666,
#  'idf': 0.016666666666666666,
#  'vectors': 0.016666666666666666,
#  'normalized': 0.016666666666666666,
#  'lengths': 0.016666666666666666,
#  'explored': 0.016666666666666666,
#  'unweighted': 0.016666666666666666,
#  'values': 0.016666666666666666,
#  'experimented': 0.016666666666666666,
#  'weights': 0.05,
#  'equal': 0.016666666666666666,
#  'continuous': 0.016666666666666666,
#  'formed': 0.016666666666666666,
#  'combining': 0.016666666666666666,
#  'cutoff': 0.016666666666666666,
#  'worth': 0.016666666666666666,
#  'noting': 0.016666666666666666,
#  'described': 0.03333333333333333,
#  'mead': 0.016666666666666666,
#  'combines': 0.016666666666666666,
#  'linear': 0.016666666666666666,
#  'combination': 0.016666666666666666,
#  'tuned': 0.016666666666666666,
#  'additional': 0.016666666666666666,
#  'absolutely': 0.016666666666666666,
#  'necessary': 0.016666666666666666,
#  'distinction': 0.016666666666666666,
#  'remains': 0.016666666666666666,
#  'cases': 0.03333333333333333,
#  'choose': 0.016666666666666666,
#  'grown': 0.016666666666666666,
#  'greater': 0.016666666666666666,
#  'risk': 0.016666666666666666,
#  'duplicate': 0.016666666666666666,
#  'place': 0.016666666666666666,
#  'event': 0.016666666666666666,
#  'distinct': 0.016666666666666666,
#  'ideas': 0.03333333333333333,
#  'address': 0.016666666666666666,
#  'applies': 0.03333333333333333,
#  'heuristic': 0.03333333333333333,
#  'adding': 0.016666666666666666,
#  'discards': 0.016666666666666666,
#  'ones': 0.016666666666666666,
#  'cross': 0.016666666666666666,
#  'subsumption': 0.016666666666666666,
#  'csis': 0.03333333333333333,
#  'great': 0.016666666666666666,
#  'stems': 0.016666666666666666,
#  'recommending': 0.016666666666666666,
#  'turn': 0.016666666666666666,
#  'intuitive': 0.016666666666666666,
#  'sense': 0.016666666666666666,
#  'allows': 0.03333333333333333,
#  'independent': 0.016666666666666666,
#  'indicating': 0.016666666666666666,
#  'vary': 0.016666666666666666,
#  'considerably': 0.016666666666666666,
#  'biomedical': 0.016666666666666666,
#  'recommendation"-based': 0.016666666666666666,
#  'procedure': 0.03333333333333333,
#  'aimed': 0.016666666666666666,
#  'texts': 0.016666666666666666,
#  'written': 0.016666666666666666,
#  'report': 0.016666666666666666,
#  'users': 0.016666666666666666,
#  'professional': 0.016666666666666666,
#  'consumers': 0.016666666666666666,
#  'quickly': 0.016666666666666666,
#  'familiarize': 0.016666666666666666,
#  'contained': 0.016666666666666666,
#  'complementing': 0.016666666666666666,
#  'aggregators': 0.016666666666666666,
#  'performing': 0.016666666666666666,
#  'road': 0.016666666666666666,
#  'coping': 0.016666666666666666,
#  'overload': 0.016666666666666666,
#  'response': 0.016666666666666666,
#  'question.[11': 0.016666666666666666,
#  'reports': 0.016666666666666666,
#  'concise': 0.016666666666666666,
#  'comprehensive': 0.03333333333333333,
#  'opinions': 0.016666666666666666,
#  'outlined': 0.016666666666666666,
#  'perspectives': 0.016666666666666666,
#  'goal': 0.016666666666666666,
#  'brief': 0.016666666666666666,
#  'simplify': 0.016666666666666666,
#  'cut': 0.016666666666666666,
#  'pointing': 0.016666666666666666,
#  'required': 0.03333333333333333,
#  'limiting': 0.016666666666666666,
#  'accessing': 0.016666666666666666,
#  'files': 0.016666666666666666,
#  'refinement': 0.016666666666666666,
#  'extracted': 0.016666666666666666,
#  'sources': 0.016666666666666666,
#  'algorithmically': 0.016666666666666666,
#  'editorial': 0.016666666666666666,
#  'touch': 0.016666666666666666,
#  'subjective': 0.016666666666666666,
#  'intervention': 0.016666666666666666,
#  'making': 0.016666666666666666,
#  'completely': 0.016666666666666666,
#  'unbiased.[dubious': 0.016666666666666666,
#  '–': 0.016666666666666666,
#  'discuss': 0.016666666666666666,
#  'incorporating': 0.016666666666666666,
#  'faces': 0.016666666666666666,
#  'potential': 0.016666666666666666,
#  'redundancy': 0.05,
#  'diverse': 0.016666666666666666,
#  'differ': 0.016666666666666666,
#  'deals': 0.016666666666666666,
#  'stage': 0.016666666666666666,
#  'mmr),[12': 0.016666666666666666,
#  'eliminate': 0.016666666666666666,
#  'page': 0.016666666666666666,
#  'lex': 0.016666666666666666,
#  'handles': 0.016666666666666666,
#  'unified': 0.016666666666666666,
#  'mathematical': 0.016666666666666666,
#  'framework': 0.016666666666666666,
#  'absorbing': 0.05,
#  'markov': 0.016666666666666666,
#  'chain': 0.016666666666666666,
#  'standard': 0.016666666666666666,
#  'states': 0.03333333333333333,
#  'act': 0.016666666666666666,
#  'black': 0.016666666666666666,
#  'holes': 0.016666666666666666,
#  'cause': 0.016666666666666666,
#  'abruptly': 0.016666666666666666,
#  'state': 0.08333333333333333,
#  'grasshopper.[13': 0.016666666666666666,
#  'addition': 0.016666666666666666,
#  'explicitly': 0.016666666666666666,
#  'promoting': 0.016666666666666666,
#  'grasshopper': 0.016666666666666666,
#  'incorporates': 0.016666666666666666,
#  'prior': 0.016666666666666666,
#  'art': 0.06666666666666667,
#  'mixtures': 0.03333333333333333,
#  'functions': 0.25,
#  'achieved': 0.05,
#  'corpora': 0.016666666666666666,
#  '04': 0.016666666666666666,
#  '07.[14': 0.016666666666666666,
#  'processes': 0.016666666666666666,
#  'special': 0.06666666666666667,
#  'duc-04.[15': 0.016666666666666666,
#  'lingual': 0.016666666666666666,
#  'avoids': 0.016666666666666666,
#  'works': 0.03333333333333333,
#  'simplifying': 0.016666666666666666,
#  'ideograms': 0.05,
#  'represent': 0.03333333333333333,
#  'meaning': 0.03333333333333333,
#  'evaluates': 0.016666666666666666,
#  'qualitatively': 0.016666666666666666,
#  'comparing': 0.016666666666666666,
#  'shape': 0.016666666666666666,
#  'said': 0.016666666666666666,
#  'recently': 0.03333333333333333,
#  'tool': 0.03333333333333333,
#  'frequency': 0.016666666666666666,
#  'preprocessing': 0.016666666666666666,
#  'kind': 0.016666666666666666,
#  'supplied': 0.016666666666666666,
#  'equivalence': 0.016666666666666666,
#  'equivalent': 0.016666666666666666,
#  'desired': 0.016666666666666666,
#  'tools': 0.016666666666666666,
#  'emerged': 0.016666666666666666,
#  'powerful': 0.016666666666666666,
#  'representation': 0.016666666666666666,
#  'combinatorial': 0.016666666666666666,
#  'optimization': 0.1,
#  'subset': 0.016666666666666666,
#  'facility': 0.03333333333333333,
#  'location': 0.03333333333333333,
#  'seen': 0.016666666666666666,
#  'encouraging': 0.016666666666666666,
#  'efficiently': 0.016666666666666666,
#  'combine': 0.016666666666666666,
#  'supervision': 0.016666666666666666,
#  'right': 0.03333333333333333,
#  'fitting': 0.016666666666666666,
#  'admit': 0.016666666666666666,
#  'efficient': 0.016666666666666666,
#  'simple': 0.03333333333333333,
#  'greedy': 0.03333333333333333,
#  'admits': 0.016666666666666666,
#  'constant': 0.016666666666666666,
#  'guarantee.[16': 0.016666666666666666,
#  'extremely': 0.016666666666666666,
#  'implement': 0.016666666666666666,
#  'scale': 0.016666666666666666,
#  'datasets': 0.03333333333333333,
#  'lin': 0.03333333333333333,
#  'bilmes': 0.03333333333333333,
#  '2012[17': 0.016666666666666666,
#  'shows': 0.03333333333333333,
#  'achieve': 0.03333333333333333,
#  'date': 0.016666666666666666,
#  'duc-04': 0.016666666666666666,
#  'duc-05': 0.016666666666666666,
#  'duc-06': 0.016666666666666666,
#  'duc-07': 0.016666666666666666,
#  '2011,[18': 0.016666666666666666,
#  'breakthrough': 0.016666666666666666,
#  'establishing': 0.016666666666666666,
#  'problems.[citation': 0.016666666666666666,
#  'tschiatschek': 0.016666666666666666,
#  'et': 0.03333333333333333,
#  'al': 0.03333333333333333,
#  '2014': 0.016666666666666666,
#  'show[19': 0.016666666666666666,
#  'bairi': 0.016666666666666666,
#  '2015[20': 0.016666666666666666,
#  'utility': 0.016666666666666666,
#  'hierarchies': 0.016666666666666666}

# %%
sentence_tokens = [token for token in document.sents]

# %%
sentence_tokens
# Out:
# [
#  there are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#  ,
#  an example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  this problem is called multi-document summarization.,
#  a related application is summarizing news articles.,
#  imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#  ,
#  image collection summarization is another application example of automatic summarization.,
#  it consists in selecting a representative set of images from a larger set of images.[4],
#  a summary in this context is useful to show the most representative images of results in an image collection exploration system.,
#  video summarization is a related domain, where the system automatically creates a trailer of a long video.,
#  this also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.,
#  similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#  ,
#  at a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.,
#  this is also called the core-set.,
#  these algorithms model notions like diversity, coverage, information and representativeness of the summary.,
#  query based summarization techniques, additionally model for relevance of the summary with the query.,
#  some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.
#  ,
#  keyphrase extraction,
#  the task is the following.,
#  you are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s,
#  that capture the primary topics discussed in the text.[5] in the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases.,
#  for example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below.,
#  consider the example text from a news article:
#  ,
#  "the army corps of engineers, rushing to meet president bush's promise to protect new orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by the associated press".,
#  a keyphrase extractor might select "army corps of engineers", "president bush", "new orleans", and "defective flood-control pumps" as keyphrases.,
#  these are pulled directly from the text.,
#  in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".,
#  abstraction requires a deep understanding of the text, which makes it difficult for a computer system.,
#  keyphrases have many applications.,
#  they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#  ,
#  depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#  ,
#  supervised learning approaches
#  beginning with the work of turney,[6],
#  many researchers have approached keyphrase extraction as a supervised machine learning problem.,
#  given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).,
#  we then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?).,
#  we assume there are known keyphrases available for a set of training documents.,
#  using the known keyphrases, we can assign positive or negative labels to the examples.,
#  then we learn a classifier that can discriminate between positive and negative examples as a function of the features.,
#  some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase.,
#  for instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases.,
#  after training a learner, we can select keyphrases for test documents in the following manner.,
#  we apply the same example-generation strategy to the test documents, then run each example through the learner.,
#  we can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model.,
#  if probabilities are given, a threshold is used to select the keyphrases.,
#  keyphrase extractors are generally evaluated using precision and recall.,
#  precision measures how many of the proposed keyphrases are actually correct.,
#  recall measures how many of the true keyphrases your system proposed.,
#  the two measures can be combined in an f-score, which is the harmonic mean of the two (f = 2pr/(p + r) ).,
#  matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#  ,
#  designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too).,
#  the first choice is exactly how to generate examples.,
#  turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords.,
#  hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags.,
#  ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case.,
#  for example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words.,
#  thus, recall may suffer.,
#  however, generating too many examples can also lead to low precision.
#  ,
#  we also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases.,
#  typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc.,
#  the turney paper used about 12 such features.,
#  hulth uses a reduced set of features, which were found most successful in the kea (keyphrase extraction algorithm),
#  work derived from turney’s seminal paper.
#  ,
#  in the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number.,
#  ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases.,
#  this is the technique used by turney with c4.5 decision trees.,
#  hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#  ,
#  once examples and features are created, we need a way to learn to predict keyphrases.,
#  virtually any supervised learning algorithm could be used, such as decision trees, naive bayes, and rule induction.,
#  in the case of turney's genex algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm.,
#  the extractor follows a series of heuristics to identify keyphrases.,
#  the genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#  ,
#  unsupervised approach:,
#  textrank,
#  another keyphrase extraction algorithm is textrank.,
#  while supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data.,
#  many documents with known keyphrases are needed.,
#  furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of turney's results demonstrate.,
#  unsupervised keyphrase extraction removes the need for training data.,
#  it approaches the problem from a different angle.,
#  instead of trying to learn explicit features that characterize keyphrases, the textrank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that pagerank selects important web pages.,
#  recall,
#  this is based on the notion of "prestige" or "recommendation" from social networks.,
#  in this way, textrank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.,
#  thus the algorithm is easily portable to new domains and languages.
#  ,
#  textrank is a general purpose graph-based ranking algorithm for nlp.,
#  essentially, it runs pagerank on a graph specially designed for a particular nlp task.,
#  for keyphrase extraction, it builds a graph using some set of text units as vertices.,
#  edges are based on some measure of semantic or lexical similarity between the text unit vertices.,
#  unlike pagerank, the edges are typically undirected and can be weighted to reflect a degree of similarity.,
#  once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#  ,
#  the vertices should correspond to what we want to rank.,
#  potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc.,
#  however, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases.,
#  this has a nice side effect of allowing us to produce keyphrases of arbitrary length.,
#  for example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.,
#  note that the unigrams placed in the graph can be filtered by part of speech.,
#  the authors found that adjectives and nouns were the best to include.,
#  thus, some linguistic knowledge comes into play in this step.
#  ,
#  edges are created based on word co-occurrence in this application of textrank.,
#  two vertices are connected by an edge if the unigrams appear within a window of size n in the original text.,
#  n is typically around 2–10.,
#  thus, "natural" and "language" might be linked in a text about nlp.,
#  "natural" and "processing" would also be linked because they would both appear in the same string of n words.,
#  these edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#  ,
#  since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases.,
#  the technique chosen is to set a count t to be a user-specified fraction of the total number of vertices in the graph.,
#  then the top t vertices/unigrams are selected based on their stationary probabilities.,
#  a post- processing step is then applied to merge adjacent instances of these t unigrams.,
#  as a result, potentially more or less than t final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#  ,
#  it is not initially clear why applying pagerank to a co-occurrence graph would produce useful keyphrases.,
#  one way to think about it is the following.,
#  a word that appears multiple times throughout a text may have many different co-occurring neighbors.,
#  for example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.,
#  thus, the "learning" vertex would be a central "hub" that connects to these other modifying words.,
#  running pagerank/textrank on the graph is likely to rank "learning" highly.,
#  similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification".,
#  if "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised".,
#  if it ends up with a high rank, it will be selected as one of the top t unigrams, along with "learning" and probably "classification".,
#  in the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#  ,
#  in short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts.,
#  a random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters.,
#  this is similar to densely connected web pages getting ranked highly by pagerank.,
#  this approach has also been used in document summarization, considered below.
#  ,
#  document summarization
#  like keyphrase extraction, document summarization aims to identify the essence of a text.,
#  the only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#  ,
#  before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.,
#  the most common way is using the so-called rouge (recall-oriented understudy for gisting evaluation) measure.,
#  this is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references.,
#  it is recall-based to encourage systems to include all the important topics in the text.,
#  recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching.,
#  for example, rouge-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#  ,
#  if there are multiple references, the rouge-1 scores are averaged.,
#  because rouge is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.,
#  high-order n-gram rouge measures try to judge fluency to some degree.,
#  note that rouge is similar to the bleu measure for machine translation, but bleu is precision- based, because translation systems favor accuracy.
#  ,
#  a promising line in document summarization is adaptive document/text summarization.[8],
#  the idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.,
#  first summarizes that perform adaptive summarization have been created.[9]
#  ,
#  supervised learning approaches,
#  supervised text summarization is very much like supervised keyphrase extraction.,
#  basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.,
#  features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc.,
#  the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".,
#  this is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient.,
#  the sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.,
#  note, however, that these natural summaries can still be used for evaluation purposes, since rouge-1 only cares about unigrams.
#  ,
#  maximum entropy-based summarization
#  during the duc 2001 and 2002 evaluation workshops,
#  , tno developed a sentence extraction system for multi-document summarization in the news domain.,
#  the system was based on a hybrid system using a naive bayes classifier and statistical language models for modeling salience.,
#  although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (me) classifier for the meeting summarization task, as me is known to be robust against feature dependencies.,
#  maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#  ,
#  textrank and lexrank
#  the unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.,
#  some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.,
#  then the sentences can be ranked with regard to their similarity to this centroid sentence.
#  ,
#  a more principled way to estimate sentence importance is using random walks and eigenvector centrality.,
#  lexrank[10] is an algorithm essentially identical to textrank, and both use this approach for document summarization.,
#  the two methods were developed by different groups at the same time, and lexrank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other nlp ranking task.
#  ,
#  in both lexrank and textrank, a graph is constructed by creating a vertex for each sentence in the document.
#  ,
#  the edges between sentences are based on some form of semantic similarity or content overlap.,
#  while lexrank uses cosine similarity of tf-idf vectors, textrank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).,
#  the lexrank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score.,
#  textrank uses continuous similarity scores as weights.
#  ,
#  in both algorithms, the sentences are ranked by applying pagerank to the resulting graph.,
#  a summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#  ,
#  it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.,
#  in this case, some training documents might be needed, though the textrank results show the additional features are not absolutely necessary.
#  ,
#  another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.,
#  the task remains the same in both cases—only the number of sentences to choose from has grown.,
#  however, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary.,
#  imagine you have a cluster of news articles on a particular event, and you want to produce one summary.,
#  each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary.,
#  to address this issue, lexrank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.,
#  the method used is called cross-sentence information subsumption (csis).
#  ,
#  these methods work based on the idea that sentences "recommend" other similar sentences to the reader.,
#  thus, if one sentence is very similar to many others, it will likely be a sentence of great importance.,
#  the importance of this sentence also stems from the importance of the sentences "recommending" it.,
#  thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.,
#  this makes intuitive sense and allows the algorithms to be applied to any arbitrary new text.,
#  the methods are domain-independent and easily portable.,
#  one could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain.,
#  however, the unsupervised "recommendation"-based approach applies to any domain.
#  ,
#  multi-document summarization
#  main article: multi-document summarization,
#  multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.,
#  resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents.,
#  in such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.,
#  multi-document summarization may also be done in response to a question.[11]
#  ,
#  multi-document summarization creates information reports that are both concise and comprehensive.,
#  with different opinions being put together and outlined, every topic is described from multiple perspectives within a single document.,
#  while the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.,
#  automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#  ,
#  incorporating diversity
#  multi-document extractive summarization faces a problem of potential redundancy.,
#  ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another).,
#  lexrank deals with diversity as a heuristic final stage using csis, and other systems have used similar methods, such as maximal marginal relevance (mmr),[12] in trying to eliminate redundancy in information retrieval results.,
#  there is a general purpose graph-based ranking algorithm like page/lex/textrank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing markov chain random walks.,
#  (an absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.),
#  the algorithm is called grasshopper.[13] in addition to explicitly promoting diversity during the ranking process, grasshopper incorporates a prior ranking (based on sentence position in the case of summarization).
#  ,
#  the state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.,
#  these methods have achieved the state of the art results for document summarization corpora, duc 04 - 07.[14],
#  similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
#  a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.,
#  this tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance,
#  (how long is the desired summary).
#  ,
#  submodular functions as generic tools for summarization,
#  the idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.,
#  submodular functions naturally model notions of coverage, information, representation and diversity.,
#  moreover, several important combinatorial optimization problems occur as special instances of submodular optimization.,
#  for example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.,
#  the set cover function attempts to find a subset of objects which cover a given set of concepts.,
#  for example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.,
#  this is an instance of set cover.,
#  similarly, the facility location problem is a special case of submodular functions.,
#  the facility location function also naturally models coverage and diversity.,
#  another example of a submodular optimization problem is using a determinantal point process to model diversity.,
#  similarly, the maximum-marginal-relevance procedure can also be seen as an instance of submodular optimization.,
#  all these important models encouraging coverage, diversity and information are all submodular.,
#  moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular.,
#  hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#  ,
#  while submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization.,
#  for example, a simple greedy algorithm admits a constant factor guarantee.[16],
#  moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#  ,
#  submodular functions have achieved state-of-the-art for almost all summarization problems.,
#  for example, work by lin and bilmes, 2012[17] shows that submodular functions achieve the best results to date on duc-04, duc-05, duc-06 and duc-07 systems for document summarization.,
#  similarly, work by lin and bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.,
#  this was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#  ,
#  submodular functions have also been used for other summarization tasks.,
#  tschiatschek,
#  et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.,
#  similarly, bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies.,
#  submodular functions have also successfully been used for summarizing machine learning datasets]

# %%
document
# Out:
# there are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
# an example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). this problem is called multi-document summarization. a related application is summarizing news articles. imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
# image collection summarization is another application example of automatic summarization. it consists in selecting a representative set of images from a larger set of images.[4] a summary in this context is useful to show the most representative images of results in an image collection exploration system. video summarization is a related domain, where the system automatically creates a trailer of a long video. this also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#
# at a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. this is also called the core-set. these algorithms model notions like diversity, coverage, information and representativeness of the summary. query based summarization techniques, additionally model for relevance of the summary with the query. some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.
#
# keyphrase extraction
# the task is the following. you are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] in the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. for example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. consider the example text from a news article:
#
# "the army corps of engineers, rushing to meet president bush's promise to protect new orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by the associated press".
# a keyphrase extractor might select "army corps of engineers", "president bush", "new orleans", and "defective flood-control pumps" as keyphrases. these are pulled directly from the text. in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". abstraction requires a deep understanding of the text, which makes it difficult for a computer system. keyphrases have many applications. they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
# depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#
# supervised learning approaches
# beginning with the work of turney,[6] many researchers have approached keyphrase extraction as a supervised machine learning problem. given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). we then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?). we assume there are known keyphrases available for a set of training documents. using the known keyphrases, we can assign positive or negative labels to the examples. then we learn a classifier that can discriminate between positive and negative examples as a function of the features. some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase. for instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases. after training a learner, we can select keyphrases for test documents in the following manner. we apply the same example-generation strategy to the test documents, then run each example through the learner. we can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model. if probabilities are given, a threshold is used to select the keyphrases. keyphrase extractors are generally evaluated using precision and recall. precision measures how many of the proposed keyphrases are actually correct. recall measures how many of the true keyphrases your system proposed. the two measures can be combined in an f-score, which is the harmonic mean of the two (f = 2pr/(p + r) ). matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
# designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too). the first choice is exactly how to generate examples. turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords. hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags. ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case. for example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words. thus, recall may suffer. however, generating too many examples can also lead to low precision.
#
# we also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases. typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc. the turney paper used about 12 such features. hulth uses a reduced set of features, which were found most successful in the kea (keyphrase extraction algorithm) work derived from turney’s seminal paper.
#
# in the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number. ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases. this is the technique used by turney with c4.5 decision trees. hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#
# once examples and features are created, we need a way to learn to predict keyphrases. virtually any supervised learning algorithm could be used, such as decision trees, naive bayes, and rule induction. in the case of turney's genex algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm. the extractor follows a series of heuristics to identify keyphrases. the genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#
# unsupervised approach: textrank
# another keyphrase extraction algorithm is textrank. while supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data. many documents with known keyphrases are needed. furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of turney's results demonstrate. unsupervised keyphrase extraction removes the need for training data. it approaches the problem from a different angle. instead of trying to learn explicit features that characterize keyphrases, the textrank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that pagerank selects important web pages. recall this is based on the notion of "prestige" or "recommendation" from social networks. in this way, textrank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. thus the algorithm is easily portable to new domains and languages.
#
# textrank is a general purpose graph-based ranking algorithm for nlp. essentially, it runs pagerank on a graph specially designed for a particular nlp task. for keyphrase extraction, it builds a graph using some set of text units as vertices. edges are based on some measure of semantic or lexical similarity between the text unit vertices. unlike pagerank, the edges are typically undirected and can be weighted to reflect a degree of similarity. once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
# the vertices should correspond to what we want to rank. potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc. however, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases. this has a nice side effect of allowing us to produce keyphrases of arbitrary length. for example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. note that the unigrams placed in the graph can be filtered by part of speech. the authors found that adjectives and nouns were the best to include. thus, some linguistic knowledge comes into play in this step.
#
# edges are created based on word co-occurrence in this application of textrank. two vertices are connected by an edge if the unigrams appear within a window of size n in the original text. n is typically around 2–10. thus, "natural" and "language" might be linked in a text about nlp. "natural" and "processing" would also be linked because they would both appear in the same string of n words. these edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
# since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases. the technique chosen is to set a count t to be a user-specified fraction of the total number of vertices in the graph. then the top t vertices/unigrams are selected based on their stationary probabilities. a post- processing step is then applied to merge adjacent instances of these t unigrams. as a result, potentially more or less than t final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
# it is not initially clear why applying pagerank to a co-occurrence graph would produce useful keyphrases. one way to think about it is the following. a word that appears multiple times throughout a text may have many different co-occurring neighbors. for example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. thus, the "learning" vertex would be a central "hub" that connects to these other modifying words. running pagerank/textrank on the graph is likely to rank "learning" highly. similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification". if "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised". if it ends up with a high rank, it will be selected as one of the top t unigrams, along with "learning" and probably "classification". in the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
# in short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts. a random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters. this is similar to densely connected web pages getting ranked highly by pagerank. this approach has also been used in document summarization, considered below.
#
# document summarization
# like keyphrase extraction, document summarization aims to identify the essence of a text. the only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
# before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. the most common way is using the so-called rouge (recall-oriented understudy for gisting evaluation) measure. this is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. it is recall-based to encourage systems to include all the important topics in the text. recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching. for example, rouge-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
# if there are multiple references, the rouge-1 scores are averaged. because rouge is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. high-order n-gram rouge measures try to judge fluency to some degree. note that rouge is similar to the bleu measure for machine translation, but bleu is precision- based, because translation systems favor accuracy.
#
# a promising line in document summarization is adaptive document/text summarization.[8] the idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. first summarizes that perform adaptive summarization have been created.[9]
#
# supervised learning approaches
# supervised text summarization is very much like supervised keyphrase extraction. basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc. the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". this is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient. the sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. note, however, that these natural summaries can still be used for evaluation purposes, since rouge-1 only cares about unigrams.
#
# maximum entropy-based summarization
# during the duc 2001 and 2002 evaluation workshops, tno developed a sentence extraction system for multi-document summarization in the news domain. the system was based on a hybrid system using a naive bayes classifier and statistical language models for modeling salience. although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (me) classifier for the meeting summarization task, as me is known to be robust against feature dependencies. maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
# textrank and lexrank
# the unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. then the sentences can be ranked with regard to their similarity to this centroid sentence.
#
# a more principled way to estimate sentence importance is using random walks and eigenvector centrality. lexrank[10] is an algorithm essentially identical to textrank, and both use this approach for document summarization. the two methods were developed by different groups at the same time, and lexrank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other nlp ranking task.
#
# in both lexrank and textrank, a graph is constructed by creating a vertex for each sentence in the document.
#
# the edges between sentences are based on some form of semantic similarity or content overlap. while lexrank uses cosine similarity of tf-idf vectors, textrank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). the lexrank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score. textrank uses continuous similarity scores as weights.
#
# in both algorithms, the sentences are ranked by applying pagerank to the resulting graph. a summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
# it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. in this case, some training documents might be needed, though the textrank results show the additional features are not absolutely necessary.
#
# another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization. the task remains the same in both cases—only the number of sentences to choose from has grown. however, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary. imagine you have a cluster of news articles on a particular event, and you want to produce one summary. each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary. to address this issue, lexrank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. the method used is called cross-sentence information subsumption (csis).
#
# these methods work based on the idea that sentences "recommend" other similar sentences to the reader. thus, if one sentence is very similar to many others, it will likely be a sentence of great importance. the importance of this sentence also stems from the importance of the sentences "recommending" it. thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences. this makes intuitive sense and allows the algorithms to be applied to any arbitrary new text. the methods are domain-independent and easily portable. one could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain. however, the unsupervised "recommendation"-based approach applies to any domain.
#
# multi-document summarization
# main article: multi-document summarization
# multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents. in such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. multi-document summarization may also be done in response to a question.[11]
#
# multi-document summarization creates information reports that are both concise and comprehensive. with different opinions being put together and outlined, every topic is described from multiple perspectives within a single document. while the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#
# incorporating diversity
# multi-document extractive summarization faces a problem of potential redundancy. ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another). lexrank deals with diversity as a heuristic final stage using csis, and other systems have used similar methods, such as maximal marginal relevance (mmr),[12] in trying to eliminate redundancy in information retrieval results. there is a general purpose graph-based ranking algorithm like page/lex/textrank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing markov chain random walks. (an absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.) the algorithm is called grasshopper.[13] in addition to explicitly promoting diversity during the ranking process, grasshopper incorporates a prior ranking (based on sentence position in the case of summarization).
#
# the state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. these methods have achieved the state of the art results for document summarization corpora, duc 04 - 07.[14] similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
# a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. this tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
# submodular functions as generic tools for summarization
# the idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. submodular functions naturally model notions of coverage, information, representation and diversity. moreover, several important combinatorial optimization problems occur as special instances of submodular optimization. for example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. the set cover function attempts to find a subset of objects which cover a given set of concepts. for example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. this is an instance of set cover. similarly, the facility location problem is a special case of submodular functions. the facility location function also naturally models coverage and diversity. another example of a submodular optimization problem is using a determinantal point process to model diversity. similarly, the maximum-marginal-relevance procedure can also be seen as an instance of submodular optimization. all these important models encouraging coverage, diversity and information are all submodular. moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular. hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
# while submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization. for example, a simple greedy algorithm admits a constant factor guarantee.[16] moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
# submodular functions have achieved state-of-the-art for almost all summarization problems. for example, work by lin and bilmes, 2012[17] shows that submodular functions achieve the best results to date on duc-04, duc-05, duc-06 and duc-07 systems for document summarization. similarly, work by lin and bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. this was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
# submodular functions have also been used for other summarization tasks. tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. similarly, bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies. submodular functions have also successfully been used for summarizing machine learning datasets

# %%
sentence_freq = {}
for sentence in sentence_tokens:
    for word in sentence:
        if word.text in word_freq.keys():
            if sentence not in sentence_freq.keys():
                sentence_freq[sentence] = word_freq[word.text]
            else:
                sentence_freq[sentence] += word_freq[word.text]

# %%
sentence_freq
# Out:
# {
#  there are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.: 2.216666666666667,
#  the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).: 2.4,
#  the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.: 2.9999999999999996,
#  summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#  : 3.466666666666667,
#  an example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.: 4.183333333333333,
#  sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).: 2.3833333333333337,
#  this problem is called multi-document summarization.: 2.15,
#  a related application is summarizing news articles.: 0.4833333333333333,
#  imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#  : 2.283333333333333,
#  image collection summarization is another application example of automatic summarization.: 2.6166666666666663,
#  it consists in selecting a representative set of images from a larger set of images.[4]: 0.8166666666666667,
#  a summary in this context is useful to show the most representative images of results in an image collection exploration system.: 1.1833333333333336,
#  video summarization is a related domain, where the system automatically creates a trailer of a long video.: 1.716666666666667,
#  this also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.: 0.3,
#  similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#  : 1.3000000000000003,
#  at a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.: 3.316666666666667,
#  this is also called the core-set.: 0.4,
#  these algorithms model notions like diversity, coverage, information and representativeness of the summary.: 1.4333333333333333,
#  query based summarization techniques, additionally model for relevance of the summary with the query.: 2.283333333333333,
#  some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.
#  : 3.8499999999999996,
#  keyphrase extraction: 0.6,
#  the task is the following.: 0.13333333333333333,
#  you are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s: 1.1,
#  that capture the primary topics discussed in the text.[5] in the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases.: 1.7999999999999998,
#  for example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below.: 1.65,
#  consider the example text from a news article:
#  : 1.8833333333333333,
#  "the army corps of engineers, rushing to meet president bush's promise to protect new orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by the associated press".: 1.016666666666667,
#  a keyphrase extractor might select "army corps of engineers", "president bush", "new orleans", and "defective flood-control pumps" as keyphrases.: 1.35,
#  these are pulled directly from the text.: 0.6333333333333333,
#  in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".: 2.3666666666666663,
#  abstraction requires a deep understanding of the text, which makes it difficult for a computer system.: 1.0,
#  keyphrases have many applications.: 0.5666666666666668,
#  they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#  : 5.1499999999999995,
#  depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#  : 1.6666666666666667,
#  supervised learning approaches
#  beginning with the work of turney,[6]: 0.7000000000000001,
#  many researchers have approached keyphrase extraction as a supervised machine learning problem.: 1.4166666666666665,
#  given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).: 2.65,
#  we then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?).: 0.9000000000000002,
#  we assume there are known keyphrases available for a set of training documents.: 1.4333333333333333,
#  using the known keyphrases, we can assign positive or negative labels to the examples.: 0.9833333333333334,
#  then we learn a classifier that can discriminate between positive and negative examples as a function of the features.: 0.85,
#  some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase.: 1.0166666666666666,
#  for instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases.: 1.5500000000000003,
#  after training a learner, we can select keyphrases for test documents in the following manner.: 1.1833333333333336,
#  we apply the same example-generation strategy to the test documents, then run each example through the learner.: 1.1,
#  we can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model.: 1.0333333333333337,
#  if probabilities are given, a threshold is used to select the keyphrases.: 0.8,
#  keyphrase extractors are generally evaluated using precision and recall.: 0.5833333333333333,
#  precision measures how many of the proposed keyphrases are actually correct.: 0.7166666666666668,
#  recall measures how many of the true keyphrases your system proposed.: 1.0333333333333334,
#  the two measures can be combined in an f-score, which is the harmonic mean of the two (f = 2pr/(p + r) ).: 0.31666666666666665,
#  matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#  : 2.666666666666666,
#  designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too).: 1.3833333333333333,
#  the first choice is exactly how to generate examples.: 0.23333333333333334,
#  turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords.: 0.4833333333333333,
#  hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags.: 0.4333333333333333,
#  ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case.: 1.2166666666666668,
#  for example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words.: 1.4999999999999998,
#  thus, recall may suffer.: 0.15,
#  however, generating too many examples can also lead to low precision.
#  : 1.0166666666666666,
#  we also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases.: 2.2333333333333334,
#  typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc.: 2.266666666666666,
#  the turney paper used about 12 such features.: 0.4166666666666667,
#  hulth uses a reduced set of features, which were found most successful in the kea (keyphrase extraction algorithm): 1.6166666666666667,
#  work derived from turney’s seminal paper.
#  : 0.95,
#  in the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number.: 2.1999999999999997,
#  ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases.: 1.4,
#  this is the technique used by turney with c4.5 decision trees.: 0.21666666666666665,
#  hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#  : 1.6500000000000001,
#  once examples and features are created, we need a way to learn to predict keyphrases.: 1.4000000000000001,
#  virtually any supervised learning algorithm could be used, such as decision trees, naive bayes, and rule induction.: 0.9833333333333334,
#  in the case of turney's genex algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm.: 2.0833333333333335,
#  the extractor follows a series of heuristics to identify keyphrases.: 0.65,
#  the genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#  : 1.85,
#  unsupervised approach:: 0.2,
#  textrank: 0.2833333333333333,
#  another keyphrase extraction algorithm is textrank.: 1.15,
#  while supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data.: 1.95,
#  many documents with known keyphrases are needed.: 0.9666666666666668,
#  furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of turney's results demonstrate.: 1.4833333333333336,
#  unsupervised keyphrase extraction removes the need for training data.: 1.1333333333333333,
#  it approaches the problem from a different angle.: 0.35000000000000003,
#  instead of trying to learn explicit features that characterize keyphrases, the textrank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that pagerank selects important web pages.: 3.866666666666666,
#  recall: 0.13333333333333333,
#  this is based on the notion of "prestige" or "recommendation" from social networks.: 0.44999999999999996,
#  in this way, textrank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.: 2.7333333333333334,
#  thus the algorithm is easily portable to new domains and languages.
#  : 1.1666666666666665,
#  textrank is a general purpose graph-based ranking algorithm for nlp.: 1.4166666666666665,
#  essentially, it runs pagerank on a graph specially designed for a particular nlp task.: 0.65,
#  for keyphrase extraction, it builds a graph using some set of text units as vertices.: 1.95,
#  edges are based on some measure of semantic or lexical similarity between the text unit vertices.: 1.4833333333333334,
#  unlike pagerank, the edges are typically undirected and can be weighted to reflect a degree of similarity.: 0.5666666666666667,
#  once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#  : 2.4833333333333334,
#  the vertices should correspond to what we want to rank.: 0.33333333333333337,
#  potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc.: 1.0833333333333335,
#  however, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases.: 1.9833333333333332,
#  this has a nice side effect of allowing us to produce keyphrases of arbitrary length.: 0.9000000000000001,
#  for example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.: 2.516666666666667,
#  note that the unigrams placed in the graph can be filtered by part of speech.: 0.6166666666666667,
#  the authors found that adjectives and nouns were the best to include.: 0.25,
#  thus, some linguistic knowledge comes into play in this step.
#  : 0.8666666666666667,
#  edges are created based on word co-occurrence in this application of textrank.: 1.1,
#  two vertices are connected by an edge if the unigrams appear within a window of size n in the original text.: 1.3833333333333333,
#  n is typically around 2–10.: 0.16666666666666666,
#  thus, "natural" and "language" might be linked in a text about nlp.: 0.8166666666666667,
#  "natural" and "processing" would also be linked because they would both appear in the same string of n words.: 0.5499999999999999,
#  these edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#  : 2.2333333333333334,
#  since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases.: 1.5833333333333335,
#  the technique chosen is to set a count t to be a user-specified fraction of the total number of vertices in the graph.: 1.1833333333333333,
#  then the top t vertices/unigrams are selected based on their stationary probabilities.: 0.95,
#  a post- processing step is then applied to merge adjacent instances of these t unigrams.: 0.7,
#  as a result, potentially more or less than t final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#  : 2.4333333333333336,
#  it is not initially clear why applying pagerank to a co-occurrence graph would produce useful keyphrases.: 1.3833333333333333,
#  one way to think about it is the following.: 0.23333333333333334,
#  a word that appears multiple times throughout a text may have many different co-occurring neighbors.: 1.1333333333333333,
#  for example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.: 3.2999999999999994,
#  thus, the "learning" vertex would be a central "hub" that connects to these other modifying words.: 0.5166666666666666,
#  running pagerank/textrank on the graph is likely to rank "learning" highly.: 1.1833333333333336,
#  similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification".: 1.6500000000000001,
#  if "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised".: 0.7333333333333334,
#  if it ends up with a high rank, it will be selected as one of the top t unigrams, along with "learning" and probably "classification".: 0.8833333333333333,
#  in the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#  : 2.4833333333333334,
#  in short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts.: 0.9000000000000002,
#  a random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters.: 0.8000000000000003,
#  this is similar to densely connected web pages getting ranked highly by pagerank.: 0.7333333333333333,
#  this approach has also been used in document summarization, considered below.
#  : 2.4333333333333336,
#  document summarization
#  like keyphrase extraction, document summarization aims to identify the essence of a text.: 4.699999999999999,
#  the only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#  : 2.25,
#  before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.: 2.466666666666667,
#  the most common way is using the so-called rouge (recall-oriented understudy for gisting evaluation) measure.: 0.6833333333333336,
#  this is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references.: 2.15,
#  it is recall-based to encourage systems to include all the important topics in the text.: 1.5166666666666666,
#  recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching.: 0.39999999999999997,
#  for example, rouge-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#  : 2.583333333333333,
#  if there are multiple references, the rouge-1 scores are averaged.: 0.26666666666666666,
#  because rouge is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.: 2.4833333333333334,
#  high-order n-gram rouge measures try to judge fluency to some degree.: 0.41666666666666663,
#  note that rouge is similar to the bleu measure for machine translation, but bleu is precision- based, because translation systems favor accuracy.
#  : 1.8666666666666667,
#  a promising line in document summarization is adaptive document/text summarization.[8]: 2.9666666666666663,
#  the idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.: 3.6999999999999997,
#  first summarizes that perform adaptive summarization have been created.[9]
#  : 1.8166666666666667,
#  supervised learning approaches: 0.5833333333333333,
#  supervised text summarization is very much like supervised keyphrase extraction.: 2.9666666666666663,
#  basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.: 2.0500000000000003,
#  features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc.: 2.4833333333333334,
#  the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".: 4.716666666666667,
#  this is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient.: 0.7166666666666667,
#  the sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.: 2.4000000000000004,
#  note, however, that these natural summaries can still be used for evaluation purposes, since rouge-1 only cares about unigrams.
#  : 1.3166666666666667,
#  maximum entropy-based summarization
#  during the duc 2001 and 2002 evaluation workshops: 1.6,
#  , tno developed a sentence extraction system for multi-document summarization in the news domain.: 3.083333333333333,
#  the system was based on a hybrid system using a naive bayes classifier and statistical language models for modeling salience.: 1.2333333333333334,
#  although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (me) classifier for the meeting summarization task, as me is known to be robust against feature dependencies.: 2.066666666666667,
#  maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#  : 2.283333333333333,
#  textrank and lexrank
#  the unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.: 2.9333333333333336,
#  some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.: 3.1166666666666667,
#  then the sentences can be ranked with regard to their similarity to this centroid sentence.
#  : 1.7,
#  a more principled way to estimate sentence importance is using random walks and eigenvector centrality.: 0.7666666666666666,
#  lexrank[10] is an algorithm essentially identical to textrank, and both use this approach for document summarization.: 2.4333333333333336,
#  the two methods were developed by different groups at the same time, and lexrank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other nlp ranking task.
#  : 3.216666666666667,
#  in both lexrank and textrank, a graph is constructed by creating a vertex for each sentence in the document.
#  : 2.3666666666666667,
#  the edges between sentences are based on some form of semantic similarity or content overlap.: 1.2833333333333334,
#  while lexrank uses cosine similarity of tf-idf vectors, textrank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).: 2.833333333333333,
#  the lexrank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score.: 0.9333333333333336,
#  textrank uses continuous similarity scores as weights.
#  : 1.2833333333333334,
#  in both algorithms, the sentences are ranked by applying pagerank to the resulting graph.: 1.2166666666666668,
#  a summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#  : 2.466666666666667,
#  it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.: 4.449999999999998,
#  in this case, some training documents might be needed, though the textrank results show the additional features are not absolutely necessary.
#  : 2.0666666666666664,
#  another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.: 4.316666666666666,
#  the task remains the same in both cases—only the number of sentences to choose from has grown.: 0.8666666666666667,
#  however, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary.: 1.6166666666666665,
#  imagine you have a cluster of news articles on a particular event, and you want to produce one summary.: 1.15,
#  each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary.: 1.5333333333333334,
#  to address this issue, lexrank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.: 2.9000000000000004,
#  the method used is called cross-sentence information subsumption (csis).
#  : 1.4000000000000001,
#  these methods work based on the idea that sentences "recommend" other similar sentences to the reader.: 1.9333333333333333,
#  thus, if one sentence is very similar to many others, it will likely be a sentence of great importance.: 0.9166666666666667,
#  the importance of this sentence also stems from the importance of the sentences "recommending" it.: 0.9833333333333334,
#  thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.: 2.3833333333333333,
#  this makes intuitive sense and allows the algorithms to be applied to any arbitrary new text.: 1.0333333333333332,
#  the methods are domain-independent and easily portable.: 0.4333333333333333,
#  one could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain.: 1.5499999999999998,
#  however, the unsupervised "recommendation"-based approach applies to any domain.
#  : 1.1,
#  multi-document summarization
#  main article: multi-document summarization: 3.9166666666666665,
#  multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.: 2.783333333333333,
#  resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents.: 1.5833333333333337,
#  in such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.: 2.849999999999999,
#  multi-document summarization may also be done in response to a question.[11]
#  : 2.6166666666666663,
#  multi-document summarization creates information reports that are both concise and comprehensive.: 2.25,
#  with different opinions being put together and outlined, every topic is described from multiple perspectives within a single document.: 1.0999999999999999,
#  while the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.: 3.3,
#  automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#  : 1.6166666666666674,
#  incorporating diversity
#  multi-document extractive summarization faces a problem of potential redundancy.: 2.3666666666666663,
#  ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another).: 1.1333333333333333,
#  lexrank deals with diversity as a heuristic final stage using csis, and other systems have used similar methods, such as maximal marginal relevance (mmr),[12] in trying to eliminate redundancy in information retrieval results.: 1.7333333333333336,
#  there is a general purpose graph-based ranking algorithm like page/lex/textrank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing markov chain random walks.: 2.3999999999999995,
#  (an absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.): 1.0500000000000003,
#  the algorithm is called grasshopper.[13] in addition to explicitly promoting diversity during the ranking process, grasshopper incorporates a prior ranking (based on sentence position in the case of summarization).
#  : 3.466666666666667,
#  the state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.: 2.9833333333333334,
#  these methods have achieved the state of the art results for document summarization corpora, duc 04 - 07.[14]: 2.233333333333333,
#  similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
#  a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.: 6.216666666666664,
#  this tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance: 1.9666666666666668,
#  (how long is the desired summary).
#  : 1.1833333333333333,
#  submodular functions as generic tools for summarization: 1.7666666666666666,
#  the idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.: 2.166666666666667,
#  submodular functions naturally model notions of coverage, information, representation and diversity.: 1.4333333333333333,
#  moreover, several important combinatorial optimization problems occur as special instances of submodular optimization.: 1.0666666666666667,
#  for example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.: 2.616666666666667,
#  the set cover function attempts to find a subset of objects which cover a given set of concepts.: 1.2500000000000002,
#  for example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.: 3.6166666666666667,
#  this is an instance of set cover.: 0.44999999999999996,
#  similarly, the facility location problem is a special case of submodular functions.: 1.2166666666666668,
#  the facility location function also naturally models coverage and diversity.: 0.6166666666666667,
#  another example of a submodular optimization problem is using a determinantal point process to model diversity.: 1.5,
#  similarly, the maximum-marginal-relevance procedure can also be seen as an instance of submodular optimization.: 0.9333333333333332,
#  all these important models encouraging coverage, diversity and information are all submodular.: 1.2166666666666668,
#  moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular.: 1.4000000000000001,
#  hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#  : 2.966666666666667,
#  while submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization.: 2.05,
#  for example, a simple greedy algorithm admits a constant factor guarantee.[16]: 0.7500000000000001,
#  moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#  : 2.45,
#  submodular functions have achieved state-of-the-art for almost all summarization problems.: 1.9833333333333334,
#  for example, work by lin and bilmes, 2012[17] shows that submodular functions achieve the best results to date on duc-04, duc-05, duc-06 and duc-07 systems for document summarization.: 3.3,
#  similarly, work by lin and bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.: 2.3,
#  this was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#  : 2.65,
#  submodular functions have also been used for other summarization tasks.: 1.7166666666666668,
#  tschiatschek: 0.016666666666666666,
#  et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.: 2.3,
#  similarly, bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies.: 1.9666666666666666,
#  submodular functions have also successfully been used for summarizing machine learning datasets: 1.1333333333333335}

# %%
length_max = int(len(sentence_freq) * .3)

# %%
length_max
# Out:
# 69

# %%
summary = nlargest(length_max, sentence_freq, key=sentence_freq.get)

# %%
summary
# Out:
# [similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
#  a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.,
#  they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#  ,
#  the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".,
#  document summarization
#  like keyphrase extraction, document summarization aims to identify the essence of a text.,
#  it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.,
#  another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.,
#  an example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  multi-document summarization
#  main article: multi-document summarization,
#  instead of trying to learn explicit features that characterize keyphrases, the textrank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that pagerank selects important web pages.,
#  some techniques and algorithms which naturally model summarization problems are textrank and pagerank, submodular set function, determinantal point process, maximal marginal relevance (mmr) etc.
#  ,
#  the idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.,
#  for example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.,
#  summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#  ,
#  the algorithm is called grasshopper.[13] in addition to explicitly promoting diversity during the ranking process, grasshopper incorporates a prior ranking (based on sentence position in the case of summarization).
#  ,
#  at a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.,
#  while the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.,
#  for example, work by lin and bilmes, 2012[17] shows that submodular functions achieve the best results to date on duc-04, duc-05, duc-06 and duc-07 systems for document summarization.,
#  for example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.,
#  the two methods were developed by different groups at the same time, and lexrank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other nlp ranking task.
#  ,
#  some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.,
#  , tno developed a sentence extraction system for multi-document summarization in the news domain.,
#  the second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  the state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.,
#  hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#  ,
#  a promising line in document summarization is adaptive document/text summarization.[8],
#  supervised text summarization is very much like supervised keyphrase extraction.,
#  textrank and lexrank
#  the unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.,
#  to address this issue, lexrank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.,
#  in such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.,
#  while lexrank uses cosine similarity of tf-idf vectors, textrank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).,
#  multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.,
#  in this way, textrank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.,
#  matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#  ,
#  given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).,
#  this was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#  ,
#  for example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.,
#  image collection summarization is another application example of automatic summarization.,
#  multi-document summarization may also be done in response to a question.[11]
#  ,
#  for example, rouge-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#  ,
#  for example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.,
#  once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#  ,
#  in the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#  ,
#  because rouge is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.,
#  features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc.,
#  before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.,
#  a summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#  ,
#  moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#  ,
#  as a result, potentially more or less than t final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#  ,
#  this approach has also been used in document summarization, considered below.
#  ,
#  lexrank[10] is an algorithm essentially identical to textrank, and both use this approach for document summarization.,
#  the sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.,
#  the first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  there is a general purpose graph-based ranking algorithm like page/lex/textrank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing markov chain random walks.,
#  sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.,
#  in both lexrank and textrank, a graph is constructed by creating a vertex for each sentence in the document.
#  ,
#  in contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".,
#  incorporating diversity
#  multi-document extractive summarization faces a problem of potential redundancy.,
#  similarly, work by lin and bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.,
#  et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.,
#  imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#  ,
#  query based summarization techniques, additionally model for relevance of the summary with the query.,
#  maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#  ,
#  typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc.,
#  the only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#  ,
#  multi-document summarization creates information reports that are both concise and comprehensive.,
#  we also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases.,
#  these edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#  ,
#  these methods have achieved the state of the art results for document summarization corpora, duc 04 - 07.[14]]

# %%
length_max = int(len(sentence_freq) * 0.03)
summary = nlargest(length_max, sentence_freq, key=sentence_freq.get)
summary
# Out:
# [similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]
#
#  a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.,
#  they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#  ,
#  the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".,
#  document summarization
#  like keyphrase extraction, document summarization aims to identify the essence of a text.,
#  it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.,
#  another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.]

# %%
final = [word.text for word in summary]

# %%
final
# Out:
# ['similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]\n\na new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.',
#  'they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.\n\n',
#  'the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".',
#  'document summarization\nlike keyphrase extraction, document summarization aims to identify the essence of a text.',
#  'it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.',
#  'another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.']

# %%
final_model = ' '.join(final)

# %%
final_model
# Out:
# 'similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]\n\na new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.\n\n the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". document summarization\nlike keyphrase extraction, document summarization aims to identify the essence of a text. it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.'

# %%
final_model = final_model.replace('\n', " ")
final_model
# Out:
# 'similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for duc-04.[15]  a new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. they can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.   the main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". document summarization like keyphrase extraction, document summarization aims to identify the essence of a text. it is worth noting that textrank was applied to summarization exactly as described here, while lexrank was used as part of a larger summarization system (mead) that combines the lexrank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. another important distinction is that textrank was used for single document summarization, while lexrank has been applied to multi-document summarization.'
